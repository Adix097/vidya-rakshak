# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("student_dropout_dataset_v3.csv")
df.head(10)
# Out:
#    Student_ID   Age  Gender  Family_Income Internet_Access  \
# 0           1  22.1    Male        25000.0             Yes
# 1           2  20.7    Male        25000.0             Yes
# 2           3  22.4    Male        40183.0             Yes
# 3           4  24.4    Male            NaN             Yes
# 4           5  20.5  Female        25319.0             Yes
# 5           6  20.5    Male        25000.0             Yes
# 6           7  24.5    Male        25000.0             Yes
# 7           8  22.7  Female        25000.0             Yes
# 8           9  20.0    Male        57413.0             Yes
# 9          10  22.2  Female        44930.0             Yes
#
#    Study_Hours_per_Day  Attendance_Rate  Assignment_Delay_Days  \
# 0                 3.36             86.1                      2
# 1                 4.30             68.0                      2
# 2                 4.40             70.9                      0
# 3                  NaN             82.2                      2
# 4                 4.19             75.7                      1
# 5                 4.11             89.1                      2
# 6                 3.00             78.2                      1
# 7                 2.12             86.4                      1
# 8                 4.07             97.5                      3
# 9                 2.98             82.2                      1
#
#    Travel_Time_Minutes Part_Time_Job Scholarship  Stress_Index   GPA  \
# 0                 20.4           Yes          No           5.5  0.96
# 1                 44.0            No          No           6.8  1.28
# 2                 48.9           Yes          No           5.5  1.68
# 3                 38.6            No          No           NaN  1.78
# 4                 23.0            No          No           7.0  1.48
# 5                 47.1            No         Yes           6.0  2.52
# 6                 37.4           Yes         Yes           7.3  0.64
# 7                 34.0            No         Yes           6.5  1.79
# 8                 52.1            No          No           4.2  3.08
# 9                 19.7            No          No           6.7  1.59
#
#    Semester_GPA  CGPA Semester   Department Parental_Education  Dropout
# 0          0.90  0.90   Year 1         Arts        High School        0
# 1          1.20  1.19   Year 3  Engineering           Bachelor        1
# 2          1.32  1.32   Year 1         Arts             Master        0
# 3          1.77  1.77   Year 1           CS        High School        1
# 4          0.91  0.87   Year 4     Business           Bachelor        0
# 5          2.72  2.69   Year 3     Business                NaN        0
# 6          0.33  0.44   Year 4           CS           Bachelor        0
# 7          1.14  1.14   Year 1         Arts        High School        0
# 8          2.81  2.81   Year 1           CS        High School        0
# 9          1.73  1.73   Year 1      Science             Master        0

# %%
df2=pd.read_csv("dataset.csv")
df2["Student_ID"]=range(1,len(df2)+1)
df2.head(10)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
# 5               2                12                  1      17
# 6               1                 1                  1      12
# 7               1                 9                  4      11
# 8               1                 1                  3      10
# 9               1                 1                  1      10
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
# 5                           0                      12            1
# 6                           1                       1            1
# 7                           1                       1            1
# 8                           1                       1           15
# 9                           1                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# 1                       1                       3                    4  ...
# 2                      22                      27                   10  ...
# 3                      23                      27                    6  ...
# 4                      22                      28                   10  ...
# 5                      22                      27                   10  ...
# 6                      13                      28                    8  ...
# 7                      22                      27                   10  ...
# 8                       1                       1                   10  ...
# 9                       1                      14                    5  ...
#
#    Curricular units 2nd sem (enrolled)  \
# 0                                    0
# 1                                    6
# 2                                    6
# 3                                    6
# 4                                    6
# 5                                    5
# 6                                    8
# 7                                    5
# 8                                    6
# 9                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
# 5                                      17
# 6                                       8
# 7                                       5
# 8                                       7
# 9                                      14
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
# 3                                    5                         12.400000
# 4                                    6                         13.000000
# 5                                    5                         11.500000
# 6                                    8                         14.345000
# 7                                    0                          0.000000
# 8                                    6                         14.142857
# 9                                    2                         13.500000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
# 3                                               0                9.4
# 4                                               0               13.9
# 5                                               5               16.2
# 6                                               0               15.5
# 7                                               0               15.5
# 8                                               0               16.2
# 9                                               0                8.9
#
#    Inflation rate   GDP   Dropout  Student_ID
# 0             1.4  1.74   Dropout           1
# 1            -0.3  0.79  Graduate           2
# 2             1.4  1.74   Dropout           3
# 3            -0.8 -3.12  Graduate           4
# 4            -0.3  0.79  Graduate           5
# 5             0.3 -0.92  Graduate           6
# 6             2.8 -4.06  Graduate           7
# 7             2.8 -4.06   Dropout           8
# 8             0.3 -0.92  Graduate           9
# 9             1.4  3.51   Dropout          10
#
# [10 rows x 36 columns]

# %%
ans=df.merge(df2,on='Student_ID')
ans.sample(10)
# Out:
#       Student_ID   Age Gender_x  Family_Income Internet_Access  \
# 3741        3742  22.1   Female        54408.0             Yes
# 2819        2820  17.0     Male        38171.0             Yes
# 2350        2351  23.3     Male        26611.0             Yes
# 2131        2132  21.0   Female        34161.0             Yes
# 4358        4359  22.3   Female        25000.0             Yes
# 4302        4303  18.9     Male        30617.0             Yes
# 1772        1773  19.6     Male       116671.0             Yes
# 1524        1525  20.2     Male        25000.0             Yes
# 3062        3063  20.8   Female        25000.0              No
# 3677        3678  20.7   Female        67817.0             Yes
#
#       Study_Hours_per_Day  Attendance_Rate  Assignment_Delay_Days  \
# 3741                 2.74             78.8                      0
# 2819                 5.78             72.1                      2
# 2350                 5.82             81.9                      0
# 2131                 3.60             85.8                      5
# 4358                 4.88             64.6                      3
# 4302                 4.61             50.0                      1
# 1772                 4.52             89.2                      3
# 1524                 4.65             75.0                      2
# 3062                 3.98             79.5                      1
# 3677                 2.76             82.3                      1
#
#       Travel_Time_Minutes Part_Time_Job  ...  \
# 3741                 32.7           Yes  ...
# 2819                 35.2           Yes  ...
# 2350                 17.3            No  ...
# 2131                 31.3            No  ...
# 4358                 33.6           Yes  ...
# 4302                 24.3           Yes  ...
# 1772                 18.3           Yes  ...
# 1524                 49.9            No  ...
# 3062                 17.7            No  ...
# 3677                 10.4            No  ...
#
#      Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 3741                                   0                                    5
# 2819                                   0                                    6
# 2350                                   0                                    8
# 2131                                   0                                    6
# 4358                                   0                                    6
# 4302                                  11                                   14
# 1772                                   0                                    6
# 1524                                   0                                    0
# 3062                                   0                                    6
# 3677                                   0                                    5
#
#       Curricular units 2nd sem (evaluations)  \
# 3741                                       9
# 2819                                      10
# 2350                                       8
# 2131                                       8
# 4358                                      13
# 4302                                      15
# 1772                                       7
# 1524                                       0
# 3062                                      10
# 3677                                      10
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 3741                                    5                         12.428571
# 2819                                    3                         11.000000
# 2350                                    7                         13.614286
# 2131                                    6                         12.000000
# 4358                                    1                         11.000000
# 4302                                   12                         11.833333
# 1772                                    6                         14.428571
# 1524                                    0                          0.000000
# 3062                                    4                         11.000000
# 3677                                    0                          0.000000
#
#      Curricular units 2nd sem (without evaluations) Unemployment rate  \
# 3741                                              0               9.4
# 2819                                              0              16.2
# 2350                                              0              12.7
# 2131                                              0              16.2
# 4358                                              0               7.6
# 4302                                              0               7.6
# 1772                                              0              16.2
# 1524                                              0               7.6
# 3062                                              0              12.7
# 3677                                              0               7.6
#
#      Inflation rate   GDP  Dropout_y
# 3741           -0.8 -3.12   Enrolled
# 2819            0.3 -0.92   Enrolled
# 2350            3.7 -1.70   Graduate
# 2131            0.3 -0.92   Graduate
# 4358            2.6  0.32    Dropout
# 4302            2.6  0.32    Dropout
# 1772            0.3 -0.92   Graduate
# 1524            2.6  0.32   Enrolled
# 3062            3.7 -1.70    Dropout
# 3677            2.6  0.32    Dropout
#
# [10 rows x 54 columns]

# %%
ans.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender_x', 'Family_Income', 'Internet_Access',
#        'Study_Hours_per_Day', 'Attendance_Rate', 'Assignment_Delay_Days',
#        'Travel_Time_Minutes', 'Part_Time_Job', 'Scholarship', 'Stress_Index',
#        'GPA', 'Semester_GPA', 'CGPA', 'Semester', 'Department',
#        'Parental_Education', 'Dropout_x', 'Marital status', 'Application mode',
#        'Application order', 'Course', 'Daytime/evening attendance',
#        'Previous qualification', 'Nacionality', 'Mother's qualification',
#        'Father's qualification', 'Mother's occupation', 'Father's occupation',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender_y', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
#        'Curricular units 2nd sem (without evaluations)', 'Unemployment rate',
#        'Inflation rate', 'GDP', 'Dropout_y'],
#       dtype='str')

# %%
ans['Application mode'].value_counts()
# Out:
# Application mode
# 1     1708
# 8      872
# 12     785
# 14     312
# 15     213
# 4      139
# 9      124
# 13      77
# 16      59
# 7       38
# 17      35
# 6       30
# 3       16
# 5       10
# 2        3
# 18       1
# 10       1
# 11       1
# Name: count, dtype: int64

# %%
df1=ans.drop(columns=['Displaced',"Father's occupation",'Debtor','Educational special needs','Previous qualification','Application order','Curricular units 1st sem (enrolled)','Age at enrollment', 'International','Marital status', "Mother's occupation",'Gender_y', 'Scholarship holder','Application mode','Curricular units 1st sem (evaluations)','GDP','Curricular units 1st sem (approved)','Curricular units 1st sem (grade)','Curricular units 1st sem (without evaluations)','Curricular units 2nd sem (credited)','Curricular units 2nd sem (enrolled)','Curricular units 2nd sem (evaluations)','Curricular units 2nd sem (approved)','Nacionality', "Mother's qualification",'Curricular units 2nd sem (grade)','Course', 'Daytime/evening attendance','Curricular units 2nd sem (without evaluations)',"Father's qualification", 'Unemployment rate','Inflation rate','Curricular units 1st sem (credited)','Study_Hours_per_Day','Stress_Index','Family_Income','Age','GPA','Semester_GPA','Semester','Department','Parental_Education','Internet_Access','Part_Time_Job','Scholarship'])

# %%
df1.columns
# Out:
# Index(['Student_ID', 'Gender_x', 'Attendance_Rate', 'Assignment_Delay_Days',
#        'Travel_Time_Minutes', 'CGPA', 'Dropout_x', 'Tuition fees up to date',
#        'Dropout_y'],
#       dtype='str')

# %%
df1['Dropout_x'].value_counts()
# Out:
# Dropout_x
# 0    3388
# 1    1036
# Name: count, dtype: int64

# %%
def dropout(x):
    if x == 'Dropout':
        return 1
    else:
        return 0

df1['Dropout_y'] = df1['Dropout_y'].apply(dropout)

# %%
df3 = df1[df1['Dropout_x'] == df1['Dropout_y']].copy()

# %%
df1['Dropout_y'].value_counts()
# Out:
# Dropout_y
# 0    3003
# 1    1421
# Name: count, dtype: int64

# %%
df3.shape
# Out:
# (2653, 9)

# %%
df3=df3.drop(columns=['Dropout_y'])

# %%
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2653 entries, 4 to 4423
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Student_ID               2653 non-null   int64
#  1   Gender_x                 2653 non-null   str
#  2   Attendance_Rate          2653 non-null   float64
#  3   Assignment_Delay_Days    2653 non-null   int64
#  4   Travel_Time_Minutes      2653 non-null   float64
#  5   CGPA                     2653 non-null   float64
#  6   Dropout_x                2653 non-null   int64
#  7   Tuition fees up to date  2653 non-null   int64
# dtypes: float64(3), int64(4), str(1)
# memory usage: 199.7 KB

# %%
df3.duplicated().sum()
# Out:
# np.int64(0)

# %%
df3.describe()
# Out:
#         Student_ID  Attendance_Rate  Assignment_Delay_Days  \
# count  2653.000000      2653.000000            2653.000000
# mean   2167.428571        82.173313               1.748963
# std    1271.437782         8.075436               1.307365
# min       5.000000        41.400000               0.000000
# 25%    1068.000000        76.800000               1.000000
# 50%    2146.000000        82.200000               2.000000
# 75%    3239.000000        87.600000               2.000000
# max    4424.000000       100.000000               8.000000
#
#        Travel_Time_Minutes         CGPA    Dropout_x  Tuition fees up to date
# count           2653.00000  2653.000000  2653.000000              2653.000000
# mean              30.35032     2.432748     0.129288                 0.938937
# std               11.81270     1.036146     0.335581                 0.239491
# min                5.00000     0.000000     0.000000                 0.000000
# 25%               22.40000     1.710000     0.000000                 1.000000
# 50%               30.40000     2.510000     0.000000                 1.000000
# 75%               38.50000     3.270000     0.000000                 1.000000
# max               68.00000     4.000000     1.000000                 1.000000

# %%
corr=df3.drop(columns=['Gender_x']).corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='winter')
plt.show()

# %%
df3.isnull().sum()
# Out:
# Student_ID                 0
# Gender_x                   0
# Attendance_Rate            0
# Assignment_Delay_Days      0
# Travel_Time_Minutes        0
# CGPA                       0
# Dropout_x                  0
# Tuition fees up to date    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = df3.drop(columns=["Dropout_x", "Student_ID"])
y = df3["Dropout_x"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=31,stratify=y
)

# %%
import numpy as np
import pandas as pd
import optuna
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import (
    RandomForestClassifier,
)
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
numeric_features = X.select_dtypes(include=[np.number]).columns.tolist()
categorical_features = X.select_dtypes(include=["object", "category", "string"]).columns.tolist()

numeric_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
])

categorical_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])

preprocessor = ColumnTransformer([
    ("num", numeric_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features),
])


def objective(trial):
    model_name = trial.suggest_categorical(
        "model",
        [  "xgb",
        ],
    )
    if model_name == "lgbm":
        max_depth = trial.suggest_int("lgbm_max_depth", 3, 8)
        num_leaves = trial.suggest_int("lgbm_num_leaves", 2, min(30, 2**max_depth - 1))
        model = LGBMClassifier(
            n_estimators=trial.suggest_int("lgbm_n_estimators", 100, 300),
            learning_rate=trial.suggest_float("lgbm_lr", 1e-3, 0.3, log=True),
            max_depth=max_depth,
            num_leaves=num_leaves,
            min_child_samples=trial.suggest_int("lgbm_min_child", 10, 100),
            subsample=trial.suggest_float("lgbm_subsample", 0.6, 1.0),
            colsample_bytree=trial.suggest_float("lgbm_colsample", 0.6, 1.0),
            reg_alpha=trial.suggest_float("lgbm_reg_alpha", 0.0, 5.0),
            reg_lambda=trial.suggest_float("lgbm_reg_lambda", 0.0, 5.0),
            is_unbalance=True,
            random_state=31,
            verbosity=-1,
            n_jobs=-1,
        )
    elif model_name == "xgb":
        model = XGBClassifier(
            n_estimators=trial.suggest_int("xgb_n_estimators", 50, 300),
            learning_rate=trial.suggest_float("xgb_lr", 1e-3, 0.5, log=True),
            max_depth=trial.suggest_int("xgb_max_depth", 2, 12),
            min_child_weight=trial.suggest_int("xgb_min_child", 1, 20),
            subsample=trial.suggest_float("xgb_subsample", 0.2, 1.0),
            colsample_bytree=trial.suggest_float("xgb_colsample", 0.2, 1.0),
            gamma=trial.suggest_float("xgb_gamma", 0.0, 10.0),
            reg_alpha=trial.suggest_float("xgb_reg_alpha", 0.0, 10.0),
            reg_lambda=trial.suggest_float("xgb_reg_lambda", 0.0, 10.0),
            random_state=31,
            eval_metric="logloss",
            n_jobs=-1,
        )
    elif model_name == "rf":
        cw = trial.suggest_categorical("rf_class_weight", ["balanced_subsample", "balanced", "none"])
        model = RandomForestClassifier(
            n_estimators=trial.suggest_int("rf_n_estimators", 50, 300),
            max_depth=trial.suggest_int("rf_max_depth", 2, 30),
            min_samples_split=trial.suggest_int("rf_min_split", 2, 20),
            min_samples_leaf=trial.suggest_int("rf_min_leaf", 1, 10),
            max_features=(lambda value: None if value == "none" else value)(
                trial.suggest_categorical("rf_max_features", ["sqrt", "log2", "none"])
            ),
            bootstrap=trial.suggest_categorical("rf_bootstrap", [True, False]),
            class_weight=None if cw == "none" else cw,
            random_state=31,
            n_jobs=-1,
        )
    from imblearn.over_sampling import SMOTE
    from imblearn.pipeline import Pipeline
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])
    pipe.fit(X_train, y_train)
    from sklearn.model_selection import StratifiedKFold
    cv = StratifiedKFold(
        n_splits=5,
        shuffle=True,
        random_state=31,
    )
    from sklearn.model_selection import cross_val_score
    score = cross_val_score(
        pipe,
        X_train,
        y_train,
        cv=cv,
        scoring="accuracy",
        n_jobs=-1,
        error_score="raise"
    ).mean()

    return score
study = optuna.create_study(direction="maximize")
study.optimize(
    objective,
    n_trials=100,
    show_progress_bar=True,
)
print("best_accuracy:", study.best_value)
print("best_params:", study.best_params)
# Out:
# [I 2026-07-15 19:41:48,315] A new study created in memory with name: no-name-95fecaa9-3734-43b0-a9f8-b146e6f29cee
# Best trial: 0. Best value: 0.778144:   1%|          | 1/100 [00:05<08:58,  5.44s/it]
# [I 2026-07-15 19:41:53,760] Trial 0 finished with value: 0.7781439295133756 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced', 'rf_n_estimators': 274, 'rf_max_depth': 5, 'rf_min_split': 13, 'rf_min_leaf': 6, 'rf_max_features': 'sqrt', 'rf_bootstrap': True}. Best is trial 0 with value: 0.7781439295133756.
# Best trial: 1. Best value: 0.829309:   2%|▏         | 2/100 [00:07<05:17,  3.23s/it]
# [I 2026-07-15 19:41:55,447] Trial 1 finished with value: 0.8293090455902385 and parameters: {'model': 'lgbm', 'lgbm_max_depth': 4, 'lgbm_num_leaves': 11, 'lgbm_n_estimators': 167, 'lgbm_lr': 0.11930896000735541, 'lgbm_min_child': 48, 'lgbm_subsample': 0.9370779834052624, 'lgbm_colsample': 0.836589444476999, 'lgbm_reg_alpha': 4.789416225578741, 'lgbm_reg_lambda': 1.1224120377620495}. Best is trial 1 with value: 0.8293090455902385.
# Best trial: 1. Best value: 0.829309:   3%|▎         | 3/100 [00:13<07:39,  4.74s/it]
# [I 2026-07-15 19:42:01,973] Trial 2 finished with value: 0.816934759296293 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 284, 'rf_max_depth': 15, 'rf_min_split': 14, 'rf_min_leaf': 4, 'rf_max_features': 'log2', 'rf_bootstrap': True}. Best is trial 1 with value: 0.8293090455902385.
# Best trial: 3. Best value: 0.831999:   4%|▍         | 4/100 [00:15<05:56,  3.72s/it]
# [I 2026-07-15 19:42:04,135] Trial 3 finished with value: 0.8319986667825987 and parameters: {'model': 'lgbm', 'lgbm_max_depth': 8, 'lgbm_num_leaves': 20, 'lgbm_n_estimators': 266, 'lgbm_lr': 0.06074746560116452, 'lgbm_min_child': 26, 'lgbm_subsample': 0.8637647419559474, 'lgbm_colsample': 0.7162496149766007, 'lgbm_reg_alpha': 0.33668843459908504, 'lgbm_reg_lambda': 2.7131185907011695}. Best is trial 3 with value: 0.8319986667825987.
# Best trial: 3. Best value: 0.831999:   5%|▌         | 5/100 [00:17<04:34,  2.89s/it]
# [I 2026-07-15 19:42:05,560] Trial 4 finished with value: 0.8131524794945367 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 59, 'rf_max_depth': 14, 'rf_min_split': 7, 'rf_min_leaf': 10, 'rf_max_features': 'none', 'rf_bootstrap': True}. Best is trial 3 with value: 0.8319986667825987.
# Best trial: 3. Best value: 0.831999:   6%|▌         | 6/100 [00:19<04:16,  2.73s/it]
# [I 2026-07-15 19:42:07,977] Trial 5 finished with value: 0.816934759296293 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 173, 'rf_max_depth': 14, 'rf_min_split': 20, 'rf_min_leaf': 4, 'rf_max_features': 'sqrt', 'rf_bootstrap': True}. Best is trial 3 with value: 0.8319986667825987.
# Best trial: 3. Best value: 0.831999:   7%|▋         | 7/100 [00:20<03:25,  2.21s/it]
# [I 2026-07-15 19:42:09,133] Trial 6 finished with value: 0.7905240124047185 and parameters: {'model': 'lgbm', 'lgbm_max_depth': 5, 'lgbm_num_leaves': 7, 'lgbm_n_estimators': 300, 'lgbm_lr': 0.002220354196406491, 'lgbm_min_child': 89, 'lgbm_subsample': 0.9589748967352368, 'lgbm_colsample': 0.6055404039706115, 'lgbm_reg_alpha': 2.0866927797764427, 'lgbm_reg_lambda': 1.7920607881321233}. Best is trial 3 with value: 0.8319986667825987.
# Best trial: 3. Best value: 0.831999:   8%|▊         | 8/100 [00:22<02:59,  1.95s/it]
# [I 2026-07-15 19:42:10,515] Trial 7 finished with value: 0.7436715647914675 and parameters: {'model': 'xgb', 'xgb_n_estimators': 215, 'xgb_lr': 0.003747861116653408, 'xgb_max_depth': 12, 'xgb_min_child': 11, 'xgb_subsample': 0.3222910302006569, 'xgb_colsample': 0.8859420474071951, 'xgb_gamma': 1.1651673571522814, 'xgb_reg_alpha': 7.211960409689694, 'xgb_reg_lambda': 4.190049342929024}. Best is trial 3 with value: 0.8319986667825987.
# Best trial: 3. Best value: 0.831999:   9%|▉         | 9/100 [00:24<03:17,  2.17s/it]
# [I 2026-07-15 19:42:13,162] Trial 8 finished with value: 0.7824479030808915 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 64, 'rf_max_depth': 21, 'rf_min_split': 10, 'rf_min_leaf': 4, 'rf_max_features': 'none', 'rf_bootstrap': False}. Best is trial 3 with value: 0.8319986667825987.
# Best trial: 3. Best value: 0.831999:  10%|█         | 10/100 [00:25<02:43,  1.82s/it]
# [I 2026-07-15 19:42:14,198] Trial 9 finished with value: 0.7646653914152393 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 95, 'rf_max_depth': 4, 'rf_min_split': 16, 'rf_min_leaf': 8, 'rf_max_features': 'log2', 'rf_bootstrap': False}. Best is trial 3 with value: 0.8319986667825987.
# Best trial: 10. Best value: 0.837387:  11%|█         | 11/100 [00:26<02:12,  1.49s/it]
# [I 2026-07-15 19:42:14,929] Trial 10 finished with value: 0.8373866040634148 and parameters: {'model': 'lgbm', 'lgbm_max_depth': 8, 'lgbm_num_leaves': 30, 'lgbm_n_estimators': 101, 'lgbm_lr': 0.25467666746858797, 'lgbm_min_child': 10, 'lgbm_subsample': 0.6292042839370554, 'lgbm_colsample': 0.995840045237886, 'lgbm_reg_alpha': 0.27717057803571754, 'lgbm_reg_lambda': 4.856500577262727}. Best is trial 10 with value: 0.8373866040634148.
# Best trial: 10. Best value: 0.837387:  12%|█▏        | 12/100 [00:27<01:53,  1.29s/it]
# [I 2026-07-15 19:42:15,769] Trial 11 finished with value: 0.8255441555806741 and parameters: {'model': 'lgbm', 'lgbm_max_depth': 8, 'lgbm_num_leaves': 28, 'lgbm_n_estimators': 104, 'lgbm_lr': 0.20411901976332306, 'lgbm_min_child': 13, 'lgbm_subsample': 0.629705715743192, 'lgbm_colsample': 0.9582433904310422, 'lgbm_reg_alpha': 0.12161099620908522, 'lgbm_reg_lambda': 4.929677995814276}. Best is trial 10 with value: 0.8373866040634148.
# Best trial: 10. Best value: 0.837387:  13%|█▎        | 13/100 [00:29<02:02,  1.41s/it]
# [I 2026-07-15 19:42:17,470] Trial 12 finished with value: 0.8319928701852012 and parameters: {'model': 'lgbm', 'lgbm_max_depth': 8, 'lgbm_num_leaves': 29, 'lgbm_n_estimators': 276, 'lgbm_lr': 0.05179038016875275, 'lgbm_min_child': 11, 'lgbm_subsample': 0.6589885074463626, 'lgbm_colsample': 0.6994582406644622, 'lgbm_reg_alpha': 0.11367593928101774, 'lgbm_reg_lambda': 4.6769536144460355}. Best is trial 10 with value: 0.8373866040634148.
# Best trial: 10. Best value: 0.837387:  14%|█▍        | 14/100 [00:30<02:01,  1.42s/it]
# [I 2026-07-15 19:42:18,888] Trial 13 finished with value: 0.8330840796452483 and parameters: {'model': 'lgbm', 'lgbm_max_depth': 8, 'lgbm_num_leaves': 19, 'lgbm_n_estimators': 213, 'lgbm_lr': 0.026819517499316724, 'lgbm_min_child': 34, 'lgbm_subsample': 0.7756992664934355, 'lgbm_colsample': 0.9985982265091109, 'lgbm_reg_alpha': 1.2380592743875867, 'lgbm_reg_lambda': 2.9728089484862967}. Best is trial 10 with value: 0.8373866040634148.
# Best trial: 10. Best value: 0.837387:  15%|█▌        | 15/100 [00:30<01:31,  1.08s/it]
# [I 2026-07-15 19:42:19,189] Trial 14 finished with value: 0.7894574384836102 and parameters: {'model': 'xgb', 'xgb_n_estimators': 71, 'xgb_lr': 0.4331437843107631, 'xgb_max_depth': 2, 'xgb_min_child': 1, 'xgb_subsample': 0.9516889119891014, 'xgb_colsample': 0.2686636926795012, 'xgb_gamma': 9.872178595691391, 'xgb_reg_alpha': 0.1612691565489417, 'xgb_reg_lambda': 9.825072392393864}. Best is trial 10 with value: 0.8373866040634148.
# Best trial: 10. Best value: 0.837387:  16%|█▌        | 16/100 [00:32<01:34,  1.12s/it]
# [I 2026-07-15 19:42:20,416] Trial 15 finished with value: 0.7948395791670289 and parameters: {'model': 'lgbm', 'lgbm_max_depth': 6, 'lgbm_num_leaves': 19, 'lgbm_n_estimators': 198, 'lgbm_lr': 0.012442225847398698, 'lgbm_min_child': 43, 'lgbm_subsample': 0.7566512719448304, 'lgbm_colsample': 0.980371364184436, 'lgbm_reg_alpha': 1.7479318199319995, 'lgbm_reg_lambda': 3.5324887487051932}. Best is trial 10 with value: 0.8373866040634148.
# Best trial: 10. Best value: 0.837387:
 'rf_max_depth': 30, 'rf_min_split': 2, 'rf_min_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 44 with value: 0.8395487348926179.
# Best trial: 44. Best value: 0.839549:  47%|████▋     | 47/100 [01:23<02:16,  2.57s/it]
# [I 2026-07-15 19:43:12,072] Trial 46 finished with value: 0.8363156826942586 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 128, 'rf_max_depth': 25, 'rf_min_split': 5, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 44 with value: 0.8395487348926179.
# Best trial: 44. Best value: 0.839549:  48%|████▊     | 48/100 [01:25<02:07,  2.45s/it]
# [I 2026-07-15 19:43:14,261] Trial 47 finished with value: 0.8379300350694143 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 128, 'rf_max_depth': 26, 'rf_min_split': 4, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 44 with value: 0.8395487348926179.
# Best trial: 48. Best value: 0.843315:  49%|████▉     | 49/100 [01:28<02:14,  2.63s/it]
# [I 2026-07-15 19:43:17,310] Trial 48 finished with value: 0.8433150740515318 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 197, 'rf_max_depth': 26, 'rf_min_split': 4, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  50%|█████     | 50/100 [01:31<02:12,  2.65s/it]
# [I 2026-07-15 19:43:19,991] Trial 49 finished with value: 0.8379285859200649 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 208, 'rf_max_depth': 26, 'rf_min_split': 5, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  51%|█████     | 51/100 [01:34<02:08,  2.63s/it]
# [I 2026-07-15 19:43:22,584] Trial 50 finished with value: 0.8416992725270266 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 220, 'rf_max_depth': 26, 'rf_min_split': 4, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  52%|█████▏    | 52/100 [01:36<02:03,  2.58s/it]
# [I 2026-07-15 19:43:25,057] Trial 51 finished with value: 0.8406225545604731 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 225, 'rf_max_depth': 26, 'rf_min_split': 4, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  53%|█████▎    | 53/100 [01:39<02:00,  2.56s/it]
# [I 2026-07-15 19:43:27,577] Trial 52 finished with value: 0.8416992725270266 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 233, 'rf_max_depth': 25, 'rf_min_split': 5, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  54%|█████▍    | 54/100 [01:42<02:04,  2.70s/it]
# [I 2026-07-15 19:43:30,590] Trial 53 finished with value: 0.840084920151871 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 232, 'rf_max_depth': 23, 'rf_min_split': 5, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  55%|█████▌    | 55/100 [01:45<02:06,  2.80s/it]
# [I 2026-07-15 19:43:33,631] Trial 54 finished with value: 0.829856824044286 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 236, 'rf_max_depth': 23, 'rf_min_split': 7, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  56%|█████▌    | 56/100 [01:48<02:07,  2.91s/it]
# [I 2026-07-15 19:43:36,779] Trial 55 finished with value: 0.8390096513346667 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 236, 'rf_max_depth': 21, 'rf_min_split': 5, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  57%|█████▋    | 57/100 [01:51<02:03,  2.87s/it]
# [I 2026-07-15 19:43:39,584] Trial 56 finished with value: 0.8309306437121409 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 233, 'rf_max_depth': 25, 'rf_min_split': 7, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  58%|█████▊    | 58/100 [01:53<01:55,  2.76s/it]
# [I 2026-07-15 19:43:42,061] Trial 57 finished with value: 0.8379314842187636 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 210, 'rf_max_depth': 23, 'rf_min_split': 4, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  59%|█████▉    | 59/100 [01:56<01:51,  2.72s/it]
# [I 2026-07-15 19:43:44,691] Trial 58 finished with value: 0.839011100484016 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 262, 'rf_max_depth': 27, 'rf_min_split': 4, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  60%|██████    | 60/100 [01:58<01:42,  2.55s/it]
# [I 2026-07-15 19:43:46,860] Trial 59 finished with value: 0.8277033881111787 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 217, 'rf_max_depth': 22, 'rf_min_split': 6, 'rf_min_leaf': 5, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  61%|██████    | 61/100 [02:01<01:43,  2.67s/it]
# [I 2026-07-15 19:43:49,789] Trial 60 finished with value: 0.839006753035968 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced', 'rf_n_estimators': 255, 'rf_max_depth': 27, 'rf_min_split': 4, 'rf_min_leaf': 2, 'rf_max_features': 'log2', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  62%|██████▏   | 62/100 [02:04<01:41,  2.68s/it]
# [I 2026-07-15 19:43:52,486] Trial 61 finished with value: 0.8390096513346664 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 257, 'rf_max_depth': 27, 'rf_min_split': 4, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  63%|██████▎   | 63/100 [02:06<01:38,  2.67s/it]
# [I 2026-07-15 19:43:55,137] Trial 62 finished with value: 0.8320059125293453 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 255, 'rf_max_depth': 27, 'rf_min_split': 4, 'rf_min_leaf': 4, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  64%|██████▍   | 64/100 [02:09<01:33,  2.60s/it]
# [I 2026-07-15 19:43:57,569] Trial 63 finished with value: 0.8368475205054633 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 193, 'rf_max_depth': 24, 'rf_min_split': 6, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  65%|██████▌   | 65/100 [02:11<01:28,  2.54s/it]
# [I 2026-07-15 19:43:59,980] Trial 64 finished with value: 0.8411601889690751 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 224, 'rf_max_depth': 28, 'rf_min_split': 4, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  66%|██████▌   | 66/100 [02:14<01:26,  2.55s/it]
# [I 2026-07-15 19:44:02,536] Trial 65 finished with value: 0.8363040894994638 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced', 'rf_n_estimators': 228, 'rf_max_depth': 19, 'rf_min_split': 6, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  67%|██████▋   | 67/100 [02:16<01:21,  2.48s/it]
# [I 2026-07-15 19:44:04,878] Trial 66 finished with value: 0.8363185809929572 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 194, 'rf_max_depth': 28, 'rf_min_split': 9, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  68%|██████▊   | 68/100 [02:16<00:58,  1.84s/it]
# [I 2026-07-15 19:44:05,201] Trial 67 finished with value: 0.8153088137263426 and parameters: {'model': 'xgb', 'xgb_n_estimators': 149, 'xgb_lr': 0.4370224442801733, 'xgb_max_depth': 7, 'xgb_min_child': 10, 'xgb_subsample': 0.6596292004609589, 'xgb_colsample': 0.5675838655345342, 'xgb_gamma': 4.165594893173775, 'xgb_reg_alpha': 4.018325983970833, 'xgb_reg_lambda': 0.08240879543106772}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  69%|██████▉   | 69/100 [02:19<00:59,  1.92s/it]
# [I 2026-07-15 19:44:07,330] Trial 68 finished with value: 0.8196258296380025 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 221, 'rf_max_depth': 24, 'rf_min_split': 3, 'rf_min_leaf': 5, 'rf_max_features': 'sqrt', 'rf_bootstrap': True}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  70%|███████   | 70/100 [02:21<01:05,  2.17s/it]
# [I 2026-07-15 19:44:10,086] Trial 69 finished with value: 0.8314682781207432 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 240, 'rf_max_depth': 25, 'rf_min_split': 5, 'rf_min_leaf': 4, 'rf_max_features': 'log2', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  71%|███████   | 71/100 [02:24<01:10,  2.42s/it]
# [I 2026-07-15 19:44:13,082] Trial 70 finished with value: 0.8303973567515868 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 291, 'rf_max_depth': 19, 'rf_min_split': 3, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': True}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  72%|███████▏  | 72/100 [02:27<01:12,  2.58s/it]
# [I 2026-07-15 19:44:16,026] Trial 71 finished with value: 0.8373952989595107 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 272, 'rf_max_depth': 28, 'rf_min_split': 4, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  73%|███████▎  | 73/100 [02:30<01:09,  2.58s/it]
# [I 2026-07-15 19:44:18,628] Trial 72 finished with value: 0.8320059125293453 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 245, 'rf_max_depth': 28, 'rf_min_split': 3, 'rf_min_leaf': 4, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  74%|███████▍  | 74/100 [02:35<01:31,  3.51s/it]
# [I 2026-07-15 19:44:24,307] Trial 73 finished with value: 0.7711329449613078 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 277, 'rf_max_depth': 10, 'rf_min_split': 6, 'rf_min_leaf': 3, 'rf_max_features': 'none', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  75%|███████▌  | 75/100 [02:38<01:17,  3.09s/it]
# [I 2026-07-15 19:44:26,413] Trial 74 finished with value: 0.8255456047300234 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 200, 'rf_max_depth': 28, 'rf_min_split': 5, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': True}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  76%|███████▌  | 76/100 [02:39<01:05,  2.71s/it]
# [I 2026-07-15 19:44:28,251] Trial 75 finished with value: 0.826626670144625 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 184, 'rf_max_depth': 26, 'rf_min_split': 3, 'rf_min_leaf': 5, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  77%|███████▋  | 77/100 [02:40<00:48,  2.10s/it]
# [I 2026-07-15 19:44:28,928] Trial 76 finished with value: 0.7878474335565023 and parameters: {'model': 'xgb', 'xgb_n_estimators': 299, 'xgb_lr': 0.03040827358602962, 'xgb_max_depth': 7, 'xgb_min_child': 12, 'xgb_subsample': 0.6573621149706569, 'xgb_colsample': 0.5493880019601917, 'xgb_gamma': 3.550040889427977, 'xgb_reg_alpha': 9.998809805976506, 'xgb_reg_lambda': 5.731715021179041}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  78%|███████▊  | 78/100 [02:44<01:01,  2.79s/it]
# [I 2026-07-15 19:44:33,303] Trial 77 finished with value: 0.7900008694896096 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 220, 'rf_max_depth': 28, 'rf_min_split': 7, 'rf_min_leaf': 2, 'rf_max_features': 'none', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  79%|███████▉  | 79/100 [02:46<00:48,  2.32s/it]
# [I 2026-07-15 19:44:34,552] Trial 78 finished with value: 0.832000115931948 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 100, 'rf_max_depth': 23, 'rf_min_split': 3, 'rf_min_leaf': 4, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  80%|████████  | 80/100 [02:48<00:45,  2.26s/it]
# [I 2026-07-15 19:44:36,647] Trial 79 finished with value: 0.818553459119497 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced', 'rf_n_estimators': 181, 'rf_max_depth': 26, 'rf_min_split': 18, 'rf_min_leaf': 8, 'rf_max_features': 'log2', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  81%|████████  | 81/100 [02:50<00:40,  2.14s/it]
# [I 2026-07-15 19:44:38,533] Trial 80 finished with value: 0.7280279975654291 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 268, 'rf_max_depth': 2, 'rf_min_split': 9, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  82%|████████▏ | 82/100 [02:53<00:42,  2.35s/it]
# [I 2026-07-15 19:44:41,358] Trial 81 finished with value: 0.8400878184505695 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 245, 'rf_max_depth': 20, 'rf_min_split': 5, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  83%|████████▎ | 83/100 [02:55<00:41,  2.42s/it]
# [I 2026-07-15 19:44:43,928] Trial 82 finished with value: 0.8293133930382866 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 251, 'rf_max_depth': 19, 'rf_min_split': 5, 'rf_min_leaf': 4, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  84%|████████▍ | 84/100 [02:58<00:39,  2.46s/it]
# [I 2026-07-15 19:44:46,498] Trial 83 finished with value: 0.8357780482856564 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 227, 'rf_max_depth': 17, 'rf_min_split': 4, 'rf_min_leaf': 3, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 48. Best value: 0.843315:  85%|████████▌ | 85/100 [03:00<00:36,  2.40s/it]
# [I 2026-07-15 19:44:48,770] Trial 84 finished with value: 0.8417007216763759 and parameters: {'model': 'rf', 'rf_class_weight': 'none', 'rf_n_estimators': 206, 'rf_max_depth': 29, 'rf_min_split': 3, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 48 with value: 0.8433150740515318.
# Best trial: 85. Best value: 0.843317:  86%|████████▌ | 86/100 [03:02<00:33,  2.38s/it]
# [I 2026-07-15 19:44:51,087] Trial 85 finished with value: 0.8433165232008811 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 203, 'rf_max_depth': 29, 'rf_min_split': 3, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  87%|████████▋ | 87/100 [03:05<00:32,  2.48s/it]
# [I 2026-07-15 19:44:53,800] Trial 86 finished with value: 0.8422383560849781 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 206, 'rf_max_depth': 24, 'rf_min_split': 3, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  88%|████████▊ | 88/100 [03:05<00:22,  1.89s/it]
# [I 2026-07-15 19:44:54,304] Trial 87 finished with value: 0.7442063009013709 and parameters: {'model': 'xgb', 'xgb_n_estimators': 221, 'xgb_lr': 0.0058174280756943695, 'xgb_max_depth': 9, 'xgb_min_child': 6, 'xgb_subsample': 0.41787246954208557, 'xgb_colsample': 0.7545880626599298, 'xgb_gamma': 8.168543029959665, 'xgb_reg_alpha': 6.2744964246064, 'xgb_reg_lambda': 2.937225856782903}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  89%|████████▉ | 89/100 [03:08<00:22,  2.04s/it]
# [I 2026-07-15 19:44:56,683] Trial 88 finished with value: 0.8411616381184244 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 207, 'rf_max_depth': 29, 'rf_min_split': 3, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  90%|█████████ | 90/100 [03:12<00:26,  2.67s/it]
# [I 2026-07-15 19:45:00,840] Trial 89 finished with value: 0.8287757586296843 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 206, 'rf_max_depth': 29, 'rf_min_split': 3, 'rf_min_leaf': 2, 'rf_max_features': 'none', 'rf_bootstrap': True}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  91%|█████████ | 91/100 [03:15<00:24,  2.77s/it]
# [I 2026-07-15 19:45:03,841] Trial 90 finished with value: 0.8427803379416284 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 178, 'rf_max_depth': 29, 'rf_min_split': 3, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  92%|█████████▏| 92/100 [03:18<00:21,  2.72s/it]
# [I 2026-07-15 19:45:06,433] Trial 91 finished with value: 0.8417007216763759 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 169, 'rf_max_depth': 29, 'rf_min_split': 3, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  93%|█████████▎| 93/100 [03:20<00:17,  2.53s/it]
# [I 2026-07-15 19:45:08,525] Trial 92 finished with value: 0.8417007216763759 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 169, 'rf_max_depth': 29, 'rf_min_split': 2, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  94%|█████████▍| 94/100 [03:22<00:14,  2.44s/it]
# [I 2026-07-15 19:45:10,742] Trial 93 finished with value: 0.8384720169260642 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 168, 'rf_max_depth': 29, 'rf_min_split': 2, 'rf_min_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  95%|█████████▌| 95/100 [03:24<00:11,  2.38s/it]
# [I 2026-07-15 19:45:12,981] Trial 94 finished with value: 0.8433165232008811 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 176, 'rf_max_depth': 29, 'rf_min_split': 2, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  96%|█████████▌| 96/100 [03:26<00:09,  2.36s/it]
# [I 2026-07-15 19:45:15,290] Trial 95 finished with value: 0.8373938498101614 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 169, 'rf_max_depth': 29, 'rf_min_split': 2, 'rf_min_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  97%|█████████▋| 97/100 [03:29<00:06,  2.30s/it]
# [I 2026-07-15 19:45:17,454] Trial 96 finished with value: 0.8427788887922789 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 179, 'rf_max_depth': 30, 'rf_min_split': 2, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  98%|█████████▊| 98/100 [03:32<00:05,  2.56s/it]
# [I 2026-07-15 19:45:20,628] Trial 97 finished with value: 0.8422412543836769 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 178, 'rf_max_depth': 30, 'rf_min_split': 2, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317:  99%|█████████▉| 99/100 [03:36<00:03,  3.01s/it]
# [I 2026-07-15 19:45:24,694] Trial 98 finished with value: 0.8433165232008811 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 181, 'rf_max_depth': 30, 'rf_min_split': 2, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# Best trial: 85. Best value: 0.843317: 100%|██████████| 100/100 [03:39<00:00,  2.20s/it]
# [I 2026-07-15 19:45:28,156] Trial 99 finished with value: 0.8379314842187636 and parameters: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 183, 'rf_max_depth': 30, 'rf_min_split': 2, 'rf_min_leaf': 1, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}. Best is trial 85 with value: 0.8433165232008811.
# best_accuracy: 0.8433165232008811
# best_params: {'model': 'rf', 'rf_class_weight': 'balanced_subsample', 'rf_n_estimators': 203, 'rf_max_depth': 29, 'rf_min_split': 3, 'rf_min_leaf': 2, 'rf_max_features': 'sqrt', 'rf_bootstrap': False}

# %%
import numpy as np
import pandas as pd
import optuna
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import (
    ExtraTreesClassifier,
    GradientBoostingClassifier,
    AdaBoostClassifier,
)
numeric_features = X.select_dtypes(include=[np.number]).columns.tolist()
categorical_features = X.select_dtypes(include=["object", "category", "string"]).columns.tolist()

numeric_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
])

categorical_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])

preprocessor = ColumnTransformer([
    ("num", numeric_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features),
])


def objective(trial):
    model_name = trial.suggest_categorical(
        "model",
        ["et", "gb", "ab",
        ],
    )
    if model_name == "et":
        cw = trial.suggest_categorical("et_class_weight", ["balanced_subsample", "balanced", "none"])
        model = ExtraTreesClassifier(
            n_estimators=trial.suggest_int("et_n_estimators", 50, 300),
            max_depth=trial.suggest_int("et_max_depth", 2, 30),
            min_samples_split=trial.suggest_int("et_min_split", 2, 20),
            min_samples_leaf=trial.suggest_int("et_min_leaf", 1, 10),
            max_features=(lambda value: None if value == "none" else value)(
                trial.suggest_categorical("et_max_features", ["sqrt", "log2", "none"])
            ),
            bootstrap=trial.suggest_categorical("et_bootstrap", [True, False]),
            class_weight=None if cw == "none" else cw,
            random_state=31,
        )
    elif model_name == "gb":
        model = GradientBoostingClassifier(
            loss=trial.suggest_categorical("gb_loss", ["log_loss", "exponential"]),
            learning_rate=trial.suggest_float("gb_lr", 1e-2, 0.5, log=True),
            n_estimators=trial.suggest_int("gb_n_estimators", 50, 300),
            subsample=trial.suggest_float("gb_subsample", 0.2, 1.0),
            max_depth=trial.suggest_int("gb_max_depth", 2, 8),
            min_samples_split=trial.suggest_int("gb_min_split", 2, 20),
            min_samples_leaf=trial.suggest_int("gb_min_leaf", 1, 10),
            random_state=31,
        )
    elif model_name == "ab":
        model = AdaBoostClassifier(
            n_estimators=trial.suggest_int("ab_n_estimators", 50, 200),
            learning_rate=trial.suggest_float("ab_lr", 1e-3, 2.0, log=True),
            random_state=31,
        )
    from sklearn.model_selection import cross_val_score
    from imblearn.over_sampling import SMOTE
    from imblearn.pipeline import Pipeline
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])
    from sklearn.model_selection import StratifiedKFold
    cv = StratifiedKFold(
        n_splits=5,
        shuffle=True,
        random_state=31,
    )
    score = cross_val_score(
        pipe,
        X_train,
        y_train,
        cv=cv,
        scoring="accuracy",
        n_jobs=-1,
        error_score="raise"
    ).mean()

    return score
study = optuna.create_study(direction="maximize")
study.optimize(
    objective,
    n_trials=100,
    show_progress_bar=True,
)
print("best_accuracy:", study.best_value)
print("best_params:", study.best_params)
# Out:
# [I 2026-07-15 19:45:28,255] A new study created in memory with name: no-name-2b2596c1-cf36-4d56-9fa0-9dcf535d03ab
# Best trial: 0. Best value: 0.806686:   1%|          | 1/100 [00:02<03:38,  2.21s/it]
# [I 2026-07-15 19:45:30,473] Trial 0 finished with value: 0.8066863750978175 and parameters: {'model': 'gb', 'gb_loss': 'exponential', 'gb_lr': 0.040443564120101305, 'gb_n_estimators': 129, 'gb_subsample': 0.9468866891630892, 'gb_max_depth': 3, 'gb_min_split': 14, 'gb_min_leaf': 7}. Best is trial 0 with value: 0.8066863750978175.
# Best trial: 0. Best value: 0.806686:   2%|▏         | 2/100 [00:05<04:23,  2.69s/it]
# [I 2026-07-15 19:45:33,497] Trial 1 finished with value: 0.7743804886531606 and parameters: {'model': 'ab', 'ab_n_estimators': 195, 'ab_lr': 0.017622638885183377}. Best is trial 0 with value: 0.8066863750978175.
# Best trial: 0. Best value: 0.806686:   3%|▎         | 3/100 [00:07<04:01,  2.49s/it]
# [I 2026-07-15 19:45:35,755] Trial 2 finished with value: 0.6881590006666087 and parameters: {'model': 'ab', 'ab_n_estimators': 166, 'ab_lr': 0.0011722445357533135}. Best is trial 0 with value: 0.8066863750978175.
# Best trial: 0. Best value: 0.806686:   4%|▍         | 4/100 [00:08<03:00,  1.88s/it]
# [I 2026-07-15 19:45:36,708] Trial 3 finished with value: 0.7905341564501638 and parameters: {'model': 'gb', 'gb_loss': 'log_loss', 'gb_lr': 0.06719831558404032, 'gb_n_estimators': 69, 'gb_subsample': 0.9612786813815133, 'gb_max_depth': 2, 'gb_min_split': 2, 'gb_min_leaf': 3}. Best is trial 0 with value: 0.8066863750978175.
# Best trial: 4. Best value: 0.817997:   5%|▌         | 5/100 [00:11<03:33,  2.24s/it]
# [I 2026-07-15 19:45:39,587] Trial 4 finished with value: 0.8179969857693534 and parameters: {'model': 'gb', 'gb_loss': 'log_loss', 'gb_lr': 0.12295673096595426, 'gb_n_estimators': 236, 'gb_subsample': 0.4629647890548776, 'gb_max_depth': 2, 'gb_min_split': 18, 'gb_min_leaf': 6}. Best is trial 4 with value: 0.8179969857693534.
# Best trial: 4. Best value: 0.817997:   6%|▌         | 6/100 [00:17<05:38,  3.60s/it]
# [I 2026-07-15 19:45:45,799] Trial 5 finished with value: 0.7808523896472771 and parameters: {'model': 'et', 'et_class_weight': 'balanced_subsample', 'et_n_estimators': 263, 'et_max_depth': 20, 'et_min_split': 8, 'et_min_leaf': 8, 'et_max_features': 'none', 'et_bootstrap': True}. Best is trial 4 with value: 0.8179969857693534.
# Best trial: 4. Best value: 0.817997:   7%|▋         | 7/100 [00:23<06:40,  4.31s/it]
# [I 2026-07-15 19:45:51,585] Trial 6 finished with value: 0.7786989537141698 and parameters: {'model': 'et', 'et_class_weight': 'balanced_subsample', 'et_n_estimators': 289, 'et_max_depth': 11, 'et_min_split': 15, 'et_min_leaf': 10, 'et_max_features': 'none', 'et_bootstrap': True}. Best is trial 4 with value: 0.8179969857693534.
# Best trial: 4. Best value: 0.817997:   8%|▊         | 8/100 [00:25<05:40,  3.70s/it]
# [I 2026-07-15 19:45:53,985] Trial 7 finished with value: 0.8131423354490913 and parameters: {'model': 'gb', 'gb_loss': 'exponential', 'gb_lr': 0.02527033106714987, 'gb_n_estimators': 117, 'gb_subsample': 0.652496829365627, 'gb_max_depth': 5, 'gb_min_split': 19, 'gb_min_leaf': 3}. Best is trial 4 with value: 0.8179969857693534.
# Best trial: 4. Best value: 0.817997:   9%|▉         | 9/100 [00:27<04:38,  3.06s/it]
# [I 2026-07-15 19:45:55,632] Trial 8 finished with value: 0.7743804886531606 and parameters: {'model': 'ab', 'ab_n_estimators': 111, 'ab_lr': 0.03833921049080947}. Best is trial 4 with value: 0.8179969857693534.
# Best trial: 9. Best value: 0.821234:  10%|█         | 10/100 [00:29<04:01,  2.68s/it]
# [I 2026-07-15 19:45:57,478] Trial 9 finished with value: 0.8212343854157609 and parameters: {'model': 'et', 'et_class_weight': 'balanced_subsample', 'et_n_estimators': 278, 'et_max_depth': 4, 'et_min_split': 9, 'et_min_leaf': 5, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 9 with value: 0.8212343854157609.
# Best trial: 10. Best value: 0.843305:  11%|█         | 11/100 [00:29<02:58,  2.01s/it]
# [I 2026-07-15 19:45:57,958] Trial 10 finished with value: 0.8433049300060865 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 62, 'et_max_depth': 2, 'et_min_split': 2, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 10 with value: 0.8433049300060865.
# Best trial: 11. Best value: 0.843306:  12%|█▏        | 12/100 [00:30<02:15,  1.54s/it]
# [I 2026-07-15 19:45:58,421] Trial 11 finished with value: 0.8433063791554357 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 58, 'et_max_depth': 3, 'et_min_split': 2, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  13%|█▎        | 13/100 [00:30<01:45,  1.22s/it]
# [I 2026-07-15 19:45:58,893] Trial 12 finished with value: 0.8319957684839 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 52, 'et_max_depth': 2, 'et_min_split': 2, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  14%|█▍        | 14/100 [00:31<01:26,  1.01s/it]
# [I 2026-07-15 19:45:59,427] Trial 13 finished with value: 0.839540039996522 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 56, 'et_max_depth': 2, 'et_min_split': 2, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  15%|█▌        | 15/100 [00:32<01:38,  1.16s/it]
# [I 2026-07-15 19:46:00,929] Trial 14 finished with value: 0.8109917978146829 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 120, 'et_max_depth': 11, 'et_min_split': 2, 'et_min_leaf': 3, 'et_max_features': 'log2', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  16%|█▌        | 16/100 [00:33<01:38,  1.17s/it]
# [I 2026-07-15 19:46:02,135] Trial 15 finished with value: 0.8136843173057414 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 117, 'et_max_depth': 9, 'et_min_split': 7, 'et_min_leaf': 3, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  17%|█▋        | 17/100 [00:34<01:32,  1.11s/it]
# [I 2026-07-15 19:46:03,103] Trial 16 finished with value: 0.8158406515375475 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 103, 'et_max_depth': 7, 'et_min_split': 5, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  18%|█▊        | 18/100 [00:35<01:23,  1.02s/it]
# [I 2026-07-15 19:46:03,902] Trial 17 finished with value: 0.8158319566414516 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 86, 'et_max_depth': 30, 'et_min_split': 20, 'et_min_leaf': 3, 'et_max_features': 'log2', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  19%|█▉        | 19/100 [00:37<01:44,  1.29s/it]
# [I 2026-07-15 19:46:05,814] Trial 18 finished with value: 0.8083050749210214 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 169, 'et_max_depth': 16, 'et_min_split': 5, 'et_min_leaf': 5, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  20%|██        | 20/100 [00:38<01:29,  1.12s/it]
# [I 2026-07-15 19:46:06,549] Trial 19 finished with value: 0.7997014752340375 and parameters: {'model': 'ab', 'ab_n_estimators': 51, 'ab_lr': 1.545130713714975}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  21%|██        | 21/100 [00:39<01:30,  1.14s/it]
# [I 2026-07-15 19:46:07,735] Trial 20 finished with value: 0.8120772106773325 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 168, 'et_max_depth': 7, 'et_min_split': 12, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  22%|██▏       | 22/100 [00:39<01:11,  1.10it/s]
# [I 2026-07-15 19:46:08,112] Trial 21 finished with value: 0.8260730950931803 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 51, 'et_max_depth': 2, 'et_min_split': 2, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  23%|██▎       | 23/100 [00:40<01:00,  1.27it/s]
# [I 2026-07-15 19:46:08,607] Trial 22 finished with value: 0.839540039996522 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 72, 'et_max_depth': 2, 'et_min_split': 4, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  24%|██▍       | 24/100 [00:40<00:55,  1.37it/s]
# [I 2026-07-15 19:46:09,198] Trial 23 finished with value: 0.8212329362664116 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 77, 'et_max_depth': 6, 'et_min_split': 4, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  25%|██▌       | 25/100 [00:41<00:59,  1.27it/s]
# [I 2026-07-15 19:46:10,132] Trial 24 finished with value: 0.8244674376141206 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 144, 'et_max_depth': 5, 'et_min_split': 2, 'et_min_leaf': 4, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  26%|██▌       | 26/100 [00:42<00:50,  1.46it/s]
# [I 2026-07-15 19:46:10,568] Trial 25 finished with value: 0.8136857664550907 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 50, 'et_max_depth': 2, 'et_min_split': 6, 'et_min_leaf': 2, 'et_max_features': 'none', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  27%|██▋       | 27/100 [00:43<00:58,  1.25it/s]
# [I 2026-07-15 19:46:11,650] Trial 26 finished with value: 0.8109961452627308 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 89, 'et_max_depth': 10, 'et_min_split': 4, 'et_min_leaf': 1, 'et_max_features': 'log2', 'et_bootstrap': True}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  28%|██▊       | 28/100 [00:43<00:52,  1.37it/s]
# [I 2026-07-15 19:46:12,203] Trial 27 finished with value: 0.8255311132365302 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 78, 'et_max_depth': 5, 'et_min_split': 2, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  29%|██▉       | 29/100 [00:44<00:52,  1.36it/s]
# [I 2026-07-15 19:46:12,947] Trial 28 finished with value: 0.8185751963597369 and parameters: {'model': 'ab', 'ab_n_estimators': 50, 'ab_lr': 1.7931778591595677}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  30%|███       | 30/100 [00:48<02:04,  1.78s/it]
# [I 2026-07-15 19:46:17,186] Trial 29 finished with value: 0.8067095614874068 and parameters: {'model': 'gb', 'gb_loss': 'exponential', 'gb_lr': 0.29428272435192604, 'gb_n_estimators': 288, 'gb_subsample': 0.2153352276283188, 'gb_max_depth': 8, 'gb_min_split': 2, 'gb_min_leaf': 10}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  31%|███       | 31/100 [00:55<03:43,  3.24s/it]
# [I 2026-07-15 19:46:23,822] Trial 30 finished with value: 0.8249963771266267 and parameters: {'model': 'gb', 'gb_loss': 'log_loss', 'gb_lr': 0.013300127470160548, 'gb_n_estimators': 199, 'gb_subsample': 0.6656638508288789, 'gb_max_depth': 8, 'gb_min_split': 9, 'gb_min_leaf': 10}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  32%|███▏      | 32/100 [00:56<02:49,  2.49s/it]
# [I 2026-07-15 19:46:24,564] Trial 31 finished with value: 0.8379271367707156 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 73, 'et_max_depth': 2, 'et_min_split': 4, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 11. Best value: 0.843306:  33%|███▎      | 33/100 [00:56<02:10,  1.95s/it]
# [I 2026-07-15 19:46:25,239] Trial 32 finished with value: 0.8217589774802192 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 66, 'et_max_depth': 4, 'et_min_split': 4, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 11 with value: 0.8433063791554357.
# Best trial: 33. Best value: 0.857302:  34%|███▍      | 34/100 [00:57<01:45,  1.61s/it]
# [I 2026-07-15 19:46:26,052] Trial 33 finished with value: 0.8573022635712835 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 102, 'et_max_depth': 2, 'et_min_split': 3, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  35%|███▌      | 35/100 [00:59<01:51,  1.71s/it]
# [I 2026-07-15 19:46:28,011] Trial 34 finished with value: 0.7587543112193142 and parameters: {'model': 'ab', 'ab_n_estimators': 120, 'ab_lr': 0.09707466317077874}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  36%|███▌      | 36/100 [01:01<01:42,  1.60s/it]
# [I 2026-07-15 19:46:29,360] Trial 35 finished with value: 0.8083036257716719 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 107, 'et_max_depth': 8, 'et_min_split': 3, 'et_min_leaf': 3, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  37%|███▋      | 37/100 [01:02<01:30,  1.43s/it]
# [I 2026-07-15 19:46:30,388] Trial 36 finished with value: 0.8169217169521492 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 144, 'et_max_depth': 5, 'et_min_split': 6, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  38%|███▊      | 38/100 [01:05<01:57,  1.90s/it]
# [I 2026-07-15 19:46:33,372] Trial 37 finished with value: 0.8115410254180796 and parameters: {'model': 'gb', 'gb_loss': 'exponential', 'gb_lr': 0.34511256026384224, 'gb_n_estimators': 298, 'gb_subsample': 0.21022949606600883, 'gb_max_depth': 5, 'gb_min_split': 8, 'gb_min_leaf': 1}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  39%|███▉      | 39/100 [01:05<01:33,  1.53s/it]
# [I 2026-07-15 19:46:34,038] Trial 38 finished with value: 0.8411529432223285 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 94, 'et_max_depth': 4, 'et_min_split': 3, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  40%|████      | 40/100 [01:07<01:38,  1.64s/it]
# [I 2026-07-15 19:46:35,925] Trial 39 finished with value: 0.6951482479784367 and parameters: {'model': 'ab', 'ab_n_estimators': 107, 'ab_lr': 0.0011323757310472006}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  41%|████      | 41/100 [01:08<01:27,  1.48s/it]
# [I 2026-07-15 19:46:37,056] Trial 40 finished with value: 0.8373837057647162 and parameters: {'model': 'et', 'et_class_weight': 'balanced_subsample', 'et_n_estimators': 135, 'et_max_depth': 4, 'et_min_split': 6, 'et_min_leaf': 4, 'et_max_features': 'log2', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  42%|████▏     | 42/100 [01:09<01:10,  1.21s/it]
# [I 2026-07-15 19:46:37,623] Trial 41 finished with value: 0.8411529432223285 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 94, 'et_max_depth': 4, 'et_min_split': 3, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  43%|████▎     | 43/100 [01:10<00:59,  1.05s/it]
# [I 2026-07-15 19:46:38,300] Trial 42 finished with value: 0.8223096542329653 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 95, 'et_max_depth': 6, 'et_min_split': 3, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  44%|████▍     | 44/100 [01:10<00:50,  1.10it/s]
# [I 2026-07-15 19:46:38,881] Trial 43 finished with value: 0.836841723908066 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 100, 'et_max_depth': 4, 'et_min_split': 3, 'et_min_leaf': 3, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  45%|████▌     | 45/100 [01:11<00:52,  1.04it/s]
# [I 2026-07-15 19:46:39,957] Trial 44 finished with value: 0.819078051183955 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 113, 'et_max_depth': 7, 'et_min_split': 5, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  46%|████▌     | 46/100 [01:15<01:34,  1.75s/it]
# [I 2026-07-15 19:46:43,565] Trial 45 finished with value: 0.8012998869663507 and parameters: {'model': 'gb', 'gb_loss': 'log_loss', 'gb_lr': 0.01123790983205316, 'gb_n_estimators': 179, 'gb_subsample': 0.46518798090527186, 'gb_max_depth': 6, 'gb_min_split': 11, 'gb_min_leaf': 7}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  47%|████▋     | 47/100 [01:17<01:40,  1.90s/it]
# [I 2026-07-15 19:46:45,809] Trial 46 finished with value: 0.7986233081181348 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 131, 'et_max_depth': 27, 'et_min_split': 3, 'et_min_leaf': 4, 'et_max_features': 'none', 'et_bootstrap': True}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  48%|████▊     | 48/100 [01:18<01:30,  1.74s/it]
# [I 2026-07-15 19:46:47,159] Trial 47 finished with value: 0.8201504217024607 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 87, 'et_max_depth': 13, 'et_min_split': 7, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  49%|████▉     | 49/100 [01:21<01:40,  1.97s/it]
# [I 2026-07-15 19:46:49,673] Trial 48 finished with value: 0.7765295771382199 and parameters: {'model': 'et', 'et_class_weight': 'balanced_subsample', 'et_n_estimators': 241, 'et_max_depth': 3, 'et_min_split': 10, 'et_min_leaf': 9, 'et_max_features': 'none', 'et_bootstrap': True}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  50%|█████     | 50/100 [01:22<01:26,  1.72s/it]
# [I 2026-07-15 19:46:50,827] Trial 49 finished with value: 0.8115410254180796 and parameters: {'model': 'et', 'et_class_weight': 'balanced_subsample', 'et_n_estimators': 71, 'et_max_depth': 22, 'et_min_split': 3, 'et_min_leaf': 3, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  51%|█████     | 51/100 [01:24<01:33,  1.90s/it]
# [I 2026-07-15 19:46:53,131] Trial 50 finished with value: 0.7598469698287106 and parameters: {'model': 'ab', 'ab_n_estimators': 155, 'ab_lr': 0.2389627311991636}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  52%|█████▏    | 52/100 [01:25<01:16,  1.59s/it]
# [I 2026-07-15 19:46:53,985] Trial 51 finished with value: 0.8223024084862185 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 62, 'et_max_depth': 4, 'et_min_split': 2, 'et_min_leaf': 7, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  53%|█████▎    | 53/100 [01:26<00:57,  1.22s/it]
# [I 2026-07-15 19:46:54,351] Trial 52 finished with value: 0.8470756166130482 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 64, 'et_max_depth': 3, 'et_min_split': 2, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  54%|█████▍    | 54/100 [01:26<00:48,  1.06s/it]
# [I 2026-07-15 19:46:55,044] Trial 53 finished with value: 0.837388053212764 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 90, 'et_max_depth': 4, 'et_min_split': 3, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  55%|█████▌    | 55/100 [01:27<00:39,  1.14it/s]
# [I 2026-07-15 19:46:55,498] Trial 54 finished with value: 0.8185360693273047 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 58, 'et_max_depth': 6, 'et_min_split': 5, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  56%|█████▌    | 56/100 [01:27<00:33,  1.30it/s]
# [I 2026-07-15 19:46:56,018] Trial 55 finished with value: 0.8546155406776222 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 82, 'et_max_depth': 3, 'et_min_split': 2, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  57%|█████▋    | 57/100 [01:28<00:34,  1.25it/s]
# [I 2026-07-15 19:46:56,888] Trial 56 finished with value: 0.8508405066226127 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 79, 'et_max_depth': 2, 'et_min_split': 2, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 33. Best value: 0.857302:  58%|█████▊    | 58/100 [01:29<00:31,  1.35it/s]
# [I 2026-07-15 19:46:57,477] Trial 57 finished with value: 0.8050676752746139 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 65, 'et_max_depth': 2, 'et_min_split': 2, 'et_min_leaf': 1, 'et_max_features': 'none', 'et_bootstrap': False}. Best is trial 33 with value: 0.8573022635712835.
# Best trial: 58. Best value: 0.861611:  59%|█████▉    | 59/100 [01:29<00:30,  1.36it/s]
# [I 2026-07-15 19:46:58,213] Trial 58 finished with value: 0.8616105845868475 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 80, 'et_max_depth': 3, 'et_min_split': 20, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  60%|██████    | 60/100 [01:31<00:34,  1.14it/s]
# [I 2026-07-15 19:46:59,410] Trial 59 finished with value: 0.808303625771672 and parameters: {'model': 'et', 'et_class_weight': 'balanced_subsample', 'et_n_estimators': 81, 'et_max_depth': 8, 'et_min_split': 17, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  61%|██████    | 61/100 [01:32<00:35,  1.11it/s]
# [I 2026-07-15 19:47:00,380] Trial 60 finished with value: 0.8282308784743355 and parameters: {'model': 'gb', 'gb_loss': 'exponential', 'gb_lr': 0.13101662883550472, 'gb_n_estimators': 64, 'gb_subsample': 0.7723449283057668, 'gb_max_depth': 4, 'gb_min_split': 15, 'gb_min_leaf': 5}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  62%|██████▏   | 62/100 [01:32<00:29,  1.30it/s]
# [I 2026-07-15 19:47:00,845] Trial 61 finished with value: 0.8497710344028055 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 61, 'et_max_depth': 3, 'et_min_split': 14, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  63%|██████▎   | 63/100 [01:33<00:26,  1.42it/s]
# [I 2026-07-15 19:47:01,388] Trial 62 finished with value: 0.8513737935831667 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 66, 'et_max_depth': 3, 'et_min_split': 20, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  64%|██████▍   | 64/100 [01:34<00:33,  1.07it/s]
# [I 2026-07-15 19:47:02,871] Trial 63 finished with value: 0.858919514245138 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 79, 'et_max_depth': 3, 'et_min_split': 19, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  65%|██████▌   | 65/100 [01:36<00:43,  1.25s/it]
# [I 2026-07-15 19:47:04,858] Trial 64 finished with value: 0.8535315769643219 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 107, 'et_max_depth': 3, 'et_min_split': 20, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  66%|██████▌   | 66/100 [01:38<00:53,  1.57s/it]
# [I 2026-07-15 19:47:07,157] Trial 65 finished with value: 0.815301567979596 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 123, 'et_max_depth': 6, 'et_min_split': 19, 'et_min_leaf': 1, 'et_max_features': 'log2', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  67%|██████▋   | 67/100 [01:40<00:52,  1.59s/it]
# [I 2026-07-15 19:47:08,796] Trial 66 finished with value: 0.857841347129235 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 109, 'et_max_depth': 2, 'et_min_split': 20, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  68%|██████▊   | 68/100 [01:41<00:45,  1.42s/it]
# [I 2026-07-15 19:47:09,817] Trial 67 finished with value: 0.8250036228733733 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 109, 'et_max_depth': 5, 'et_min_split': 20, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  69%|██████▉   | 69/100 [01:42<00:39,  1.28s/it]
# [I 2026-07-15 19:47:10,763] Trial 68 finished with value: 0.8508448540706605 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 105, 'et_max_depth': 3, 'et_min_split': 18, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  70%|███████   | 70/100 [01:43<00:36,  1.22s/it]
# [I 2026-07-15 19:47:11,870] Trial 69 finished with value: 0.8519157754398169 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 122, 'et_max_depth': 2, 'et_min_split': 19, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  71%|███████   | 71/100 [01:44<00:34,  1.20s/it]
# [I 2026-07-15 19:47:13,008] Trial 70 finished with value: 0.740408080456772 and parameters: {'model': 'ab', 'ab_n_estimators': 78, 'ab_lr': 0.014387394582285027}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  72%|███████▏  | 72/100 [01:45<00:33,  1.21s/it]
# [I 2026-07-15 19:47:14,241] Trial 71 finished with value: 0.8486798249427586 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 124, 'et_max_depth': 2, 'et_min_split': 19, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  73%|███████▎  | 73/100 [01:47<00:33,  1.23s/it]
# [I 2026-07-15 19:47:15,529] Trial 72 finished with value: 0.8433063791554357 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 114, 'et_max_depth': 3, 'et_min_split': 19, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  74%|███████▍  | 74/100 [01:49<00:36,  1.40s/it]
# [I 2026-07-15 19:47:17,329] Trial 73 finished with value: 0.8206909544097615 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 154, 'et_max_depth': 5, 'et_min_split': 17, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  75%|███████▌  | 75/100 [01:50<00:34,  1.39s/it]
# [I 2026-07-15 19:47:18,683] Trial 74 finished with value: 0.849759441208011 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 132, 'et_max_depth': 2, 'et_min_split': 20, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  76%|███████▌  | 76/100 [01:51<00:33,  1.41s/it]
# [I 2026-07-15 19:47:20,130] Trial 75 finished with value: 0.850841955771962 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 101, 'et_max_depth': 3, 'et_min_split': 18, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  77%|███████▋  | 77/100 [01:53<00:34,  1.50s/it]
# [I 2026-07-15 19:47:21,864] Trial 76 finished with value: 0.8142234008636932 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 84, 'et_max_depth': 5, 'et_min_split': 18, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  78%|███████▊  | 78/100 [01:56<00:43,  1.99s/it]
# [I 2026-07-15 19:47:24,997] Trial 77 finished with value: 0.8077616439150219 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 219, 'et_max_depth': 7, 'et_min_split': 20, 'et_min_leaf': 1, 'et_max_features': 'log2', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  79%|███████▉  | 79/100 [02:01<00:56,  2.70s/it]
# [I 2026-07-15 19:47:29,333] Trial 78 finished with value: 0.7653073645769933 and parameters: {'model': 'gb', 'gb_loss': 'log_loss', 'gb_lr': 0.4634462401708498, 'gb_n_estimators': 241, 'gb_subsample': 0.40337893496868227, 'gb_max_depth': 7, 'gb_min_split': 6, 'gb_min_leaf': 1}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  80%|████████  | 80/100 [02:02<00:43,  2.18s/it]
# [I 2026-07-15 19:47:30,326] Trial 79 finished with value: 0.8449236298292903 and parameters: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 120, 'et_max_depth': 3, 'et_min_split': 19, 'et_min_leaf': 3, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  81%|████████  | 81/100 [02:03<00:35,  1.87s/it]
# [I 2026-07-15 19:47:31,464] Trial 80 finished with value: 0.855687911196128 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 97, 'et_max_depth': 2, 'et_min_split': 16, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  82%|████████▏ | 82/100 [02:04<00:30,  1.71s/it]
# [I 2026-07-15 19:47:32,798] Trial 81 finished with value: 0.855687911196128 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 99, 'et_max_depth': 2, 'et_min_split': 15, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  83%|████████▎ | 83/100 [02:05<00:25,  1.50s/it]
# [I 2026-07-15 19:47:33,816] Trial 82 finished with value: 0.8567646291626815 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 98, 'et_max_depth': 2, 'et_min_split': 15, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  84%|████████▍ | 84/100 [02:06<00:22,  1.38s/it]
# [I 2026-07-15 19:47:34,923] Trial 83 finished with value: 0.85622554560473 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 98, 'et_max_depth': 2, 'et_min_split': 15, 'et_min_leaf': 3, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  85%|████████▌ | 85/100 [02:07<00:18,  1.26s/it]
# [I 2026-07-15 19:47:35,883] Trial 84 finished with value: 0.8411500449236298 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 98, 'et_max_depth': 4, 'et_min_split': 15, 'et_min_leaf': 3, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  86%|████████▌ | 86/100 [02:08<00:15,  1.10s/it]
# [I 2026-07-15 19:47:36,623] Trial 85 finished with value: 0.8583818798365359 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 88, 'et_max_depth': 2, 'et_min_split': 15, 'et_min_leaf': 3, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  87%|████████▋ | 87/100 [02:12<00:25,  1.98s/it]
# [I 2026-07-15 19:47:40,662] Trial 86 finished with value: 0.8427658464481349 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 300, 'et_max_depth': 2, 'et_min_split': 14, 'et_min_leaf': 4, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  88%|████████▊ | 88/100 [02:14<00:24,  2.03s/it]
# [I 2026-07-15 19:47:42,801] Trial 87 finished with value: 0.7172405298090021 and parameters: {'model': 'ab', 'ab_n_estimators': 146, 'ab_lr': 0.00423719590867958}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  89%|████████▉ | 89/100 [02:16<00:21,  1.93s/it]
# [I 2026-07-15 19:47:44,505] Trial 88 finished with value: 0.8023722574848564 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 99, 'et_max_depth': 2, 'et_min_split': 15, 'et_min_leaf': 3, 'et_max_features': 'none', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  90%|█████████ | 90/100 [02:17<00:18,  1.84s/it]
# [I 2026-07-15 19:47:46,122] Trial 89 finished with value: 0.8169144712054024 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 93, 'et_max_depth': 6, 'et_min_split': 16, 'et_min_leaf': 3, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  91%|█████████ | 91/100 [02:18<00:13,  1.50s/it]
# [I 2026-07-15 19:47:46,825] Trial 90 finished with value: 0.8368475205054633 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 74, 'et_max_depth': 4, 'et_min_split': 13, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  92%|█████████▏| 92/100 [02:20<00:12,  1.62s/it]
# [I 2026-07-15 19:47:48,733] Trial 91 finished with value: 0.8562269947540795 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 85, 'et_max_depth': 2, 'et_min_split': 16, 'et_min_leaf': 2, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  93%|█████████▎| 93/100 [02:21<00:10,  1.49s/it]
# [I 2026-07-15 19:47:49,924] Trial 92 finished with value: 0.8567675274613802 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 89, 'et_max_depth': 2, 'et_min_split': 16, 'et_min_leaf': 4, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  94%|█████████▍| 94/100 [02:23<00:08,  1.46s/it]
# [I 2026-07-15 19:47:51,311] Trial 93 finished with value: 0.8465408805031448 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 88, 'et_max_depth': 4, 'et_min_split': 16, 'et_min_leaf': 4, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  95%|█████████▌| 95/100 [02:24<00:07,  1.42s/it]
# [I 2026-07-15 19:47:52,654] Trial 94 finished with value: 0.8562269947540795 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 112, 'et_max_depth': 2, 'et_min_split': 11, 'et_min_leaf': 5, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  96%|█████████▌| 96/100 [02:25<00:05,  1.35s/it]
# [I 2026-07-15 19:47:53,836] Trial 95 finished with value: 0.8271498130597339 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 113, 'et_max_depth': 5, 'et_min_split': 11, 'et_min_leaf': 5, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  97%|█████████▋| 97/100 [02:26<00:03,  1.19s/it]
# [I 2026-07-15 19:47:54,654] Trial 96 finished with value: 0.8427643972987855 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 73, 'et_max_depth': 3, 'et_min_split': 14, 'et_min_leaf': 6, 'et_max_features': 'log2', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  98%|█████████▊| 98/100 [02:29<00:03,  1.84s/it]
# [I 2026-07-15 19:47:58,022] Trial 97 finished with value: 0.8346969828710549 and parameters: {'model': 'gb', 'gb_loss': 'log_loss', 'gb_lr': 0.12140434172621709, 'gb_n_estimators': 141, 'gb_subsample': 0.8237930343634665, 'gb_max_depth': 6, 'gb_min_split': 14, 'gb_min_leaf': 8}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611:  99%|█████████▉| 99/100 [02:30<00:01,  1.64s/it]
# [I 2026-07-15 19:47:59,173] Trial 98 finished with value: 0.8363098860968611 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 109, 'et_max_depth': 4, 'et_min_split': 13, 'et_min_leaf': 5, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# Best trial: 58. Best value: 0.861611: 100%|██████████| 100/100 [02:31<00:00,  1.52s/it]
# [I 2026-07-15 19:48:00,206] Trial 99 finished with value: 0.8562240964553807 and parameters: {'model': 'et', 'et_class_weight': 'balanced', 'et_n_estimators': 86, 'et_max_depth': 2, 'et_min_split': 17, 'et_min_leaf': 6, 'et_max_features': 'sqrt', 'et_bootstrap': True}. Best is trial 58 with value: 0.8616105845868475.
# best_accuracy: 0.8616105845868475
# best_params: {'model': 'et', 'et_class_weight': 'none', 'et_n_estimators': 80, 'et_max_depth': 3, 'et_min_split': 20, 'et_min_leaf': 1, 'et_max_features': 'sqrt', 'et_bootstrap': True}

# %%
import numpy as np
import pandas as pd
import optuna
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import accuracy_score
from sklearn.linear_model import (
    RidgeClassifier,
    SGDClassifier,
)
from sklearn.neighbors import KNeighborsClassifier
numeric_features = X.select_dtypes(include=[np.number]).columns.tolist()
categorical_features = X.select_dtypes(include=["object", "category", "string"]).columns.tolist()

numeric_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
])

categorical_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])

preprocessor = ColumnTransformer([
    ("num", numeric_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features),
])
def objective(trial):
    model_name = trial.suggest_categorical(
        "model",
        ["ridge", "sgd", "knn",
        ],
    )
    if model_name == "ridge":
        model = RidgeClassifier(
            alpha=trial.suggest_float("ridge_alpha", 1e-3, 30.0, log=True),
            solver=trial.suggest_categorical("ridge_solver", ["auto","lsqr","sag"]),
        )
    elif model_name == "sgd":
        loss = trial.suggest_categorical("sgd_loss", ["hinge", "log_loss", "modified_huber", "perceptron"])
        penalty = trial.suggest_categorical("sgd_penalty", ["l2", "l1", "elasticnet"])
        if loss in ("hinge", "perceptron") and penalty == "elasticnet":
            penalty = "l2"
        model = SGDClassifier(
            alpha=trial.suggest_float("sgd_alpha", 1e-2, 1, log=True),
            max_iter=trial.suggest_int("sgd_max_iter", 500, 3000),
            loss=loss,
            penalty=penalty,
            learning_rate=trial.suggest_categorical("sgd_lr", ["optimal", "invscaling", "constant"]),
            eta0=trial.suggest_float("sgd_eta0", 1e-3, 1.0, log=True),
            random_state=31,
        )
    elif model_name == "knn":
        model = KNeighborsClassifier(
            n_neighbors=trial.suggest_int("knn_k", 1, 30),
            weights=trial.suggest_categorical("knn_weights", ["uniform", "distance"]),
            algorithm=trial.suggest_categorical("knn_alg", ["auto", "ball_tree", "kd_tree", "brute"]),
            p=trial.suggest_int("knn_p", 1, 3),
        )
    from sklearn.model_selection import cross_val_score

    from imblearn.over_sampling import SMOTE
    from imblearn.pipeline import Pipeline
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])
    pipe.fit(X_train, y_train)
    from sklearn.model_selection import StratifiedKFold
    cv = StratifiedKFold(
        n_splits=5,
        shuffle=True,
        random_state=31,
    )
    score = cross_val_score(
        pipe,
        X_train,
        y_train,
        cv=cv,
        scoring="accuracy",
        n_jobs=-1,
        error_score="raise"
    ).mean()

    return score
study = optuna.create_study(direction="maximize")
study.optimize(
    objective,
    n_trials=100,
    show_progress_bar=True,
)
print("best_accuracy:", study.best_value)
print("best_params:", study.best_params)
# Out:
# [I 2026-07-15 19:48:00,247] A new study created in memory with name: no-name-fc8f416a-d66b-4f1a-be05-121df0c0b33f
# Best trial: 1. Best value: 0.779768:   2%|▏         | 2/100 [00:00<00:14,  6.74it/s]
# [I 2026-07-15 19:48:00,427] Trial 0 finished with value: 0.7749210213604615 and parameters: {'model': 'sgd', 'sgd_loss': 'hinge', 'sgd_penalty': 'l2', 'sgd_alpha': 0.03489149939737853, 'sgd_max_iter': 2817, 'sgd_lr': 'invscaling', 'sgd_eta0': 0.0905298888664258}. Best is trial 0 with value: 0.7749210213604615.
# [I 2026-07-15 19:48:00,555] Trial 1 finished with value: 0.7797684259339768 and parameters: {'model': 'sgd', 'sgd_loss': 'modified_huber', 'sgd_penalty': 'l2', 'sgd_alpha': 0.04091953104391896, 'sgd_max_iter': 1929, 'sgd_lr': 'invscaling', 'sgd_eta0': 0.008220197580832209}. Best is trial 1 with value: 0.7797684259339768.
# Best trial: 1. Best value: 0.779768:   3%|▎         | 3/100 [00:00<00:15,  6.15it/s]
# [I 2026-07-15 19:48:00,732] Trial 2 finished with value: 0.696337999594238 and parameters: {'model': 'sgd', 'sgd_loss': 'hinge', 'sgd_penalty': 'l2', 'sgd_alpha': 0.058309819635224164, 'sgd_max_iter': 1512, 'sgd_lr': 'constant', 'sgd_eta0': 0.9041113686290299}. Best is trial 1 with value: 0.7797684259339768.
# Best trial: 1. Best value: 0.779768:   4%|▍         | 4/100 [00:00<00:20,  4.59it/s]
# [I 2026-07-15 19:48:01,037] Trial 3 finished with value: 0.7566110193316523 and parameters: {'model': 'knn', 'knn_k': 22, 'knn_weights': 'uniform', 'knn_alg': 'auto', 'knn_p': 3}. Best is trial 1 with value: 0.7797684259339768.
# Best trial: 1. Best value: 0.779768:   5%|▌         | 5/100 [00:01<00:20,  4.58it/s]
# [I 2026-07-15 19:48:01,254] Trial 4 finished with value: 0.7711503347534997 and parameters: {'model': 'knn', 'knn_k': 7, 'knn_weights': 'uniform', 'knn_alg': 'ball_tree', 'knn_p': 1}. Best is trial 1 with value: 0.7797684259339768.
# Best trial: 6. Best value: 0.803997:   7%|▋         | 7/100 [00:01<00:27,  3.39it/s]
# [I 2026-07-15 19:48:01,895] Trial 5 finished with value: 0.7549865229110513 and parameters: {'model': 'knn', 'knn_k': 5, 'knn_weights': 'uniform', 'knn_alg': 'ball_tree', 'knn_p': 3}. Best is trial 1 with value: 0.7797684259339768.
# [I 2026-07-15 19:48:02,053] Trial 6 finished with value: 0.8039967539054576 and parameters: {'model': 'knn', 'knn_k': 1, 'knn_weights': 'uniform', 'knn_alg': 'ball_tree', 'knn_p': 2}. Best is trial 6 with value: 0.8039967539054576.
. Best is trial 64 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:18,274] Trial 91 finished with value: 0.8901544793206388 and parameters: {'model': 'sgd', 'sgd_loss': 'hinge', 'sgd_penalty': 'l1', 'sgd_alpha': 0.41525053796882344, 'sgd_max_iter': 500, 'sgd_lr': 'constant', 'sgd_eta0': 0.0010747986140001932}. Best is trial 64 with value: 0.8901544793206388.
# Best trial: 64. Best value: 0.890154:  94%|█████████▍| 94/100 [00:18<00:01,  5.58it/s]
# [I 2026-07-15 19:48:18,425] Trial 92 finished with value: 0.8901544793206388 and parameters: {'model': 'sgd', 'sgd_loss': 'hinge', 'sgd_penalty': 'l1', 'sgd_alpha': 0.4663047956259802, 'sgd_max_iter': 608, 'sgd_lr': 'constant', 'sgd_eta0': 0.001658359377212578}. Best is trial 64 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:18,589] Trial 93 finished with value: 0.7808263049589891 and parameters: {'model': 'sgd', 'sgd_loss': 'hinge', 'sgd_penalty': 'l1', 'sgd_alpha': 0.26036139608255654, 'sgd_max_iter': 556, 'sgd_lr': 'constant', 'sgd_eta0': 0.002103206102145133}. Best is trial 64 with value: 0.8901544793206388.
# Best trial: 64. Best value: 0.890154:  96%|█████████▌| 96/100 [00:18<00:00,  6.18it/s]
# [I 2026-07-15 19:48:18,757] Trial 94 finished with value: 0.8223125525316639 and parameters: {'model': 'sgd', 'sgd_loss': 'hinge', 'sgd_penalty': 'l1', 'sgd_alpha': 0.3103152852087248, 'sgd_max_iter': 659, 'sgd_lr': 'constant', 'sgd_eta0': 0.001054745664178513}. Best is trial 64 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:18,889] Trial 95 finished with value: 0.2774889140074776 and parameters: {'model': 'sgd', 'sgd_loss': 'perceptron', 'sgd_penalty': 'l1', 'sgd_alpha': 0.3872858642832015, 'sgd_max_iter': 512, 'sgd_lr': 'constant', 'sgd_eta0': 0.0014918480204917726}. Best is trial 64 with value: 0.8901544793206388.
# Best trial: 64. Best value: 0.890154:  98%|█████████▊| 98/100 [00:18<00:00,  6.38it/s]
# [I 2026-07-15 19:48:19,028] Trial 96 finished with value: 0.8901544793206388 and parameters: {'model': 'sgd', 'sgd_loss': 'hinge', 'sgd_penalty': 'l1', 'sgd_alpha': 0.4581467282823948, 'sgd_max_iter': 630, 'sgd_lr': 'constant', 'sgd_eta0': 0.002471207783095109}. Best is trial 64 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:19,186] Trial 97 finished with value: 0.8519433092774541 and parameters: {'model': 'sgd', 'sgd_loss': 'hinge', 'sgd_penalty': 'l2', 'sgd_alpha': 0.6421047408250659, 'sgd_max_iter': 747, 'sgd_lr': 'constant', 'sgd_eta0': 0.0012820614888117859}. Best is trial 64 with value: 0.8901544793206388.
# Best trial: 64. Best value: 0.890154: 100%|██████████| 100/100 [00:19<00:00,  5.18it/s]
# [I 2026-07-15 19:48:19,378] Trial 98 finished with value: 0.7813885749065298 and parameters: {'model': 'sgd', 'sgd_loss': 'hinge', 'sgd_penalty': 'l1', 'sgd_alpha': 0.027667376609965884, 'sgd_max_iter': 898, 'sgd_lr': 'constant', 'sgd_eta0': 0.0017972560154342}. Best is trial 64 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:19,565] Trial 99 finished with value: 0.7684578152624411 and parameters: {'model': 'knn', 'knn_k': 12, 'knn_weights': 'uniform', 'knn_alg': 'auto', 'knn_p': 2}. Best is trial 64 with value: 0.8901544793206388.
# best_accuracy: 0.8901544793206388
# best_params: {'model': 'sgd', 'sgd_loss': 'hinge', 'sgd_penalty': 'l1', 'sgd_alpha': 0.5070110839447165, 'sgd_max_iter': 961, 'sgd_lr': 'constant', 'sgd_eta0': 0.01571404989972212}

# %%
import numpy as np
import pandas as pd
import optuna
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import (
    LogisticRegression
)
numeric_features = X.select_dtypes(include=[np.number]).columns.tolist()
categorical_features = X.select_dtypes(include=["object", "category", "string"]).columns.tolist()

numeric_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
])

categorical_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])

preprocessor = ColumnTransformer([
    ("num", numeric_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features),
])
def objective(trial):
    model_name = trial.suggest_categorical(
        "model",
        [   "logreg","gnb",
        ],
    )
    if model_name == "logreg":
        penalty = trial.suggest_categorical(
            "logreg_penalty",
            ["l1", "l2", "elasticnet"]
        )
        solver = trial.suggest_categorical(
            "logreg_solver",
            ["lbfgs", "liblinear", "saga"]
        )
        if penalty == "l1" and solver == "lbfgs":
            raise optuna.TrialPruned()
        if penalty == "elasticnet" and solver != "saga":
            raise optuna.TrialPruned()
        logreg_kwargs = dict(
            penalty=penalty,
            solver=solver,
            C=trial.suggest_float(
                "logreg_C",
                1e-3,
                60,
                log=True,
            ),
            max_iter=trial.suggest_int(
                "logreg_max_iter",
                1000,
                3000,
            ),
        )
        cw = trial.suggest_categorical(
            "logreg_class_weight",
            ["balanced", "none"],
        )
        if cw != "none":
            logreg_kwargs["class_weight"] = cw

        if penalty == "elasticnet":
            logreg_kwargs["l1_ratio"] = trial.suggest_float(
                "logreg_l1_ratio",
                0,
                1,
            )

        model = LogisticRegression(**logreg_kwargs)
    elif model_name == "gnb":
        model = GaussianNB(var_smoothing=trial.suggest_float("gnb_var_smoothing", 1e-10, 1e-6, log=True))
    from sklearn.model_selection import cross_val_score

    from imblearn.over_sampling import SMOTE
    from imblearn.pipeline import Pipeline
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])
    pipe.fit(X_train, y_train)
    from sklearn.model_selection import StratifiedKFold
    cv = StratifiedKFold(
        n_splits=5,
        shuffle=True,
        random_state=31,
    )
    score = cross_val_score(
        pipe,
        X_train,
        y_train,
        cv=cv,
        scoring="accuracy",
        n_jobs=-1,
        error_score="raise"
    ).mean()

    return score
study = optuna.create_study(direction="maximize")
study.optimize(
    objective,
    n_trials=100,
    show_progress_bar=True,
)
print("best_accuracy:", study.best_value)
print("best_params:", study.best_params)
# Out:
# [I 2026-07-15 19:48:19,599] A new study created in memory with name: no-name-589a7125-32ab-4405-a9d9-e88e3eb784c1
# Best trial: 1. Best value: 0.854618:   2%|▏         | 2/100 [00:00<00:08, 12.15it/s]
# [I 2026-07-15 19:48:19,608] Trial 0 pruned.
# [I 2026-07-15 19:48:19,767] Trial 1 finished with value: 0.8546184389763208 and parameters: {'model': 'gnb', 'gnb_var_smoothing': 2.963192270314703e-09}. Best is trial 1 with value: 0.8546184389763208.
# Best trial: 1. Best value: 0.854618:   4%|▍         | 4/100 [00:00<00:12,  7.65it/s]
# [I 2026-07-15 19:48:19,901] Trial 2 finished with value: 0.8546184389763208 and parameters: {'model': 'gnb', 'gnb_var_smoothing': 3.9024655726937315e-07}. Best is trial 1 with value: 0.8546184389763208.
# [I 2026-07-15 19:48:20,096] Trial 3 finished with value: 0.8546184389763208 and parameters: {'model': 'gnb', 'gnb_var_smoothing': 3.0498882256063155e-09}. Best is trial 1 with value: 0.8546184389763208.
# Best trial: 1. Best value: 0.854618:   6%|▌         | 6/100 [00:00<00:13,  7.17it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# [I 2026-07-15 19:48:20,243] Trial 4 finished with value: 0.8546184389763208 and parameters: {'model': 'gnb', 'gnb_var_smoothing': 8.302129711247777e-08}. Best is trial 1 with value: 0.8546184389763208.
# [I 2026-07-15 19:48:20,391] Trial 5 finished with value: 0.8546184389763208 and parameters: {'model': 'gnb', 'gnb_var_smoothing': 7.741144912537943e-09}. Best is trial 1 with value: 0.8546184389763208.
# Best trial: 1. Best value: 0.854618:   8%|▊         | 8/100 [00:01<00:21,  4.24it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# [I 2026-07-15 19:48:20,969] Trial 6 finished with value: 0.7824623945743848 and parameters: {'model': 'logreg', 'logreg_penalty': 'elasticnet', 'logreg_solver': 'saga', 'logreg_C': 5.640391511869907, 'logreg_max_iter': 1532, 'logreg_class_weight': 'balanced', 'logreg_l1_ratio': 0.48116893474650757}. Best is trial 1 with value: 0.8546184389763208.
# [I 2026-07-15 19:48:21,122] Trial 7 finished with value: 0.8546184389763208 and parameters: {'model': 'gnb', 'gnb_var_smoothing': 6.851728868480699e-08}. Best is trial 1 with value: 0.8546184389763208.
# Best trial: 1. Best value: 0.854618:  10%|█         | 10/100 [00:02<00:26,  3.37it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:21,776] Trial 8 finished with value: 0.7824623945743848 and parameters: {'model': 'logreg', 'logreg_penalty': 'l2', 'logreg_solver': 'saga', 'logreg_C': 3.8433486251448854, 'logreg_max_iter': 2795, 'logreg_class_weight': 'balanced'}. Best is trial 1 with value: 0.8546184389763208.
# [I 2026-07-15 19:48:21,927] Trial 9 finished with value: 0.8546184389763208 and parameters: {'model': 'gnb', 'gnb_var_smoothing': 1.553453438388039e-10}. Best is trial 1 with value: 0.8546184389763208.
# Best trial: 10. Best value: 0.890154:  11%|█         | 11/100 [00:02<00:22,  3.88it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  12%|█▏        | 12/100 [00:02<00:20,  4.35it/s]
# [I 2026-07-15 19:48:22,093] Trial 10 finished with value: 0.8901544793206388 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0013480802798151305, 'logreg_max_iter': 1003, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:22,253] Trial 11 finished with value: 0.8745297510361418 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0012032453818390328, 'logreg_max_iter': 1200, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  13%|█▎        | 13/100 [00:02<00:19,  4.51it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  14%|█▍        | 14/100 [00:03<00:17,  4.98it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:22,460] Trial 12 finished with value: 0.8901544793206388 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0013249420858742302, 'logreg_max_iter': 1000, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:22,613] Trial 13 finished with value: 0.87075906442918 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.001161238858525749, 'logreg_max_iter': 1022, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  15%|█▌        | 15/100 [00:03<00:16,  5.15it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  16%|█▌        | 16/100 [00:03<00:15,  5.55it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:22,787] Trial 14 finished with value: 0.7733037706866069 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.031144517096402317, 'logreg_max_iter': 1007, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:22,934] Trial 15 finished with value: 0.758761556966061 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.016630234463451677, 'logreg_max_iter': 1681, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  17%|█▋        | 17/100 [00:03<00:14,  5.69it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  17%|█▋        | 17/100 [00:03<00:14,  5.69it/s]
# [I 2026-07-15 19:48:23,104] Trial 16 finished with value: 0.7479871315537779 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.01313361033234123, 'logreg_max_iter': 1596, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:23,292] Trial 17 finished with value: 0.806692171695215 and parameters: {'model': 'logreg', 'logreg_penalty': 'l2', 'logreg_solver': 'lbfgs', 'logreg_C': 0.001175738881925915, 'logreg_max_iter': 1429, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  18%|█▊        | 18/100 [00:03<00:15,  5.32it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  19%|█▉        | 19/100 [00:04<00:21,  3.83it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:23,738] Trial 18 finished with value: 0.779769875083326 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.11066755818844785, 'logreg_max_iter': 1966, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  20%|██        | 20/100 [00:04<00:23,  3.43it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  21%|██        | 21/100 [00:04<00:19,  4.12it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:24,115] Trial 19 finished with value: 0.6704373532736284 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.005478807681973336, 'logreg_max_iter': 1302, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:24,244] Trial 20 finished with value: 0.7819233110164333 and parameters: {'model': 'logreg', 'logreg_penalty': 'l2', 'logreg_solver': 'lbfgs', 'logreg_C': 0.29831663967517086, 'logreg_max_iter': 2152, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  22%|██▏       | 22/100 [00:04<00:18,  4.25it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:24,460] Trial 21 finished with value: 0.87075906442918 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0011540090351725239, 'logreg_max_iter': 1162, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  23%|██▎       | 23/100 [00:05<00:17,  4.30it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  24%|██▍       | 24/100 [00:05<00:15,  4.81it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:24,687] Trial 22 finished with value: 0.6489029939425557 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.004206065873084875, 'logreg_max_iter': 1249, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:24,839] Trial 23 finished with value: 0.6489029939425557 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.004010502423723555, 'logreg_max_iter': 1025, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  25%|██▌       | 25/100 [00:05<00:14,  5.30it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  26%|██▌       | 26/100 [00:05<00:12,  5.90it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:24,982] Trial 24 finished with value: 0.87075906442918 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0010196574257497735, 'logreg_max_iter': 1286, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:25,108] Trial 25 finished with value: 0.792691939831319 and parameters: {'model': 'logreg', 'logreg_penalty': 'elasticnet', 'logreg_solver': 'saga', 'logreg_C': 0.005334206058854062, 'logreg_max_iter': 1784, 'logreg_class_weight': 'none', 'logreg_l1_ratio': 0.03173397183664223}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  27%|██▋       | 27/100 [00:05<00:11,  6.55it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  28%|██▊       | 28/100 [00:05<00:11,  6.45it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:25,222] Trial 26 finished with value: 0.6489029939425557 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.004582458986850433, 'logreg_max_iter': 1378, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:25,382] Trial 27 finished with value: 0.7770744572935686 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.040079063795107256, 'logreg_max_iter': 1166, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  29%|██▉       | 29/100 [00:05<00:10,  6.88it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  30%|███       | 30/100 [00:06<00:09,  7.02it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# [I 2026-07-15 19:48:25,504] Trial 28 finished with value: 0.7824623945743848 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 45.86243780552286, 'logreg_max_iter': 2870, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:25,640] Trial 29 finished with value: 0.7991507984812916 and parameters: {'model': 'logreg', 'logreg_penalty': 'l2', 'logreg_solver': 'lbfgs', 'logreg_C': 0.002512732934465639, 'logreg_max_iter': 1117, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  31%|███       | 31/100 [00:06<00:09,  7.06it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  32%|███▏      | 32/100 [00:06<00:09,  7.42it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:25,781] Trial 30 finished with value: 0.7862287337332985 and parameters: {'model': 'logreg', 'logreg_penalty': 'elasticnet', 'logreg_solver': 'saga', 'logreg_C': 0.011085678284185992, 'logreg_max_iter': 1380, 'logreg_class_weight': 'balanced', 'logreg_l1_ratio': 0.9261022161583476}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:25,898] Trial 31 finished with value: 0.87075906442918 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0011436194070994872, 'logreg_max_iter': 1047, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  33%|███▎      | 33/100 [00:06<00:08,  7.60it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  34%|███▍      | 34/100 [00:06<00:09,  7.32it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:26,023] Trial 32 finished with value: 0.6548256673332753 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0024758940088575325, 'logreg_max_iter': 1019, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:26,170] Trial 33 finished with value: 0.87075906442918 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0010252294561024155, 'logreg_max_iter': 1196, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  36%|███▌      | 36/100 [00:06<00:08,  7.15it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:26,312] Trial 34 finished with value: 0.6553633017418775 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0024254245598445234, 'logreg_max_iter': 1200, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:26,456] Trial 35 finished with value: 0.8546184389763208 and parameters: {'model': 'gnb', 'gnb_var_smoothing': 1.1567486439268093e-10}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  38%|███▊      | 38/100 [00:07<00:09,  6.83it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:26,628] Trial 36 finished with value: 0.7356027012143872 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.010208277977237834, 'logreg_max_iter': 1462, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:26,766] Trial 37 finished with value: 0.8546184389763208 and parameters: {'model': 'gnb', 'gnb_var_smoothing': 4.946343419698589e-07}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  40%|████      | 40/100 [00:07<00:08,  7.04it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:26,920] Trial 38 finished with value: 0.6580572703822856 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0021709094524527232, 'logreg_max_iter': 2493, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:27,047] Trial 39 finished with value: 0.8546184389763208 and parameters: {'model': 'gnb', 'gnb_var_smoothing': 9.27688886342425e-10}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:27,058] Trial 40 pruned.
# Best trial: 10. Best value: 0.890154:  42%|████▏     | 42/100 [00:07<00:06,  8.84it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  43%|████▎     | 43/100 [00:07<00:07,  7.66it/s]
# [I 2026-07-15 19:48:27,204] Trial 41 finished with value: 0.6623641422485 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0020502048510265985, 'logreg_max_iter': 1160, 'logreg_class_weight': 'none'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48
and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'saga', 'logreg_C': 0.0013975853904895238, 'logreg_max_iter': 1485, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  90%|█████████ | 90/100 [00:14<00:02,  4.98it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# [I 2026-07-15 19:48:33,992] Trial 89 finished with value: 0.7932252267918731 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'saga', 'logreg_C': 0.0029186163302151653, 'logreg_max_iter': 1749, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  91%|█████████ | 91/100 [00:14<00:01,  4.92it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:34,197] Trial 90 finished with value: 0.8045372866127583 and parameters: {'model': 'logreg', 'logreg_penalty': 'l2', 'logreg_solver': 'saga', 'logreg_C': 0.0013578120208666213, 'logreg_max_iter': 1851, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  92%|█████████▏| 92/100 [00:14<00:01,  4.82it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:34,413] Trial 91 finished with value: 0.8040011013535053 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'saga', 'logreg_C': 0.0020450843642337495, 'logreg_max_iter': 1490, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  93%|█████████▎| 93/100 [00:15<00:01,  4.12it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:34,730] Trial 92 finished with value: 0.8901544793206388 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'saga', 'logreg_C': 0.001383530623004555, 'logreg_max_iter': 1341, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  94%|█████████▍| 94/100 [00:15<00:01,  3.67it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  95%|█████████▌| 95/100 [00:15<00:01,  4.14it/s]
# [I 2026-07-15 19:48:35,086] Trial 93 finished with value: 0.8901544793206388 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'saga', 'logreg_C': 0.0013444507508340385, 'logreg_max_iter': 1437, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:35,255] Trial 94 finished with value: 0.7969930151001362 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'saga', 'logreg_C': 0.002403194740987398, 'logreg_max_iter': 1442, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  96%|█████████▌| 96/100 [00:15<00:00,  4.63it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  97%|█████████▋| 97/100 [00:15<00:00,  5.02it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# [I 2026-07-15 19:48:35,412] Trial 95 finished with value: 0.8901544793206388 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'saga', 'logreg_C': 0.0013629950229541229, 'logreg_max_iter': 1571, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:35,573] Trial 96 finished with value: 0.7883792713677071 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'saga', 'logreg_C': 0.004172260221140374, 'logreg_max_iter': 1650, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154:  98%|█████████▊| 98/100 [00:16<00:00,  5.42it/s]c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Barun Rawat\Desktop\vidya_rakshak\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Best trial: 10. Best value: 0.890154:  99%|█████████▉| 99/100 [00:16<00:00,  5.75it/s]
# [I 2026-07-15 19:48:35,723] Trial 97 finished with value: 0.7819146161203374 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'saga', 'logreg_C': 0.0068599193842999425, 'logreg_max_iter': 1414, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# [I 2026-07-15 19:48:35,871] Trial 98 finished with value: 0.8040011013535056 and parameters: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'saga', 'logreg_C': 0.0021107861525478553, 'logreg_max_iter': 1494, 'logreg_class_weight': 'balanced'}. Best is trial 10 with value: 0.8901544793206388.
# Best trial: 10. Best value: 0.890154: 100%|██████████| 100/100 [00:16<00:00,  6.10it/s]
# [I 2026-07-15 19:48:35,994] Trial 99 finished with value: 0.8546184389763208 and parameters: {'model': 'gnb', 'gnb_var_smoothing': 1.6366655413564153e-07}. Best is trial 10 with value: 0.8901544793206388.
# best_accuracy: 0.8901544793206388
# best_params: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0013480802798151305, 'logreg_max_iter': 1003, 'logreg_class_weight': 'none'}

# %%
import numpy as np
import pandas as pd
import optuna
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
numeric_features = X.select_dtypes(include=[np.number]).columns.tolist()
categorical_features = X.select_dtypes(include=["object", "category", "string"]).columns.tolist()
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
numeric_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
])

categorical_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])

preprocessor = ColumnTransformer([
    ("num", numeric_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features),
])
def objective(trial):
    model_name = trial.suggest_categorical(
        "model",
        [   "svc","dt",
        ],
    )
    if model_name == "svc":
        kernel = trial.suggest_categorical("svc_kernel", ["linear", "rbf", "poly", "sigmoid"])
        svc_kwargs = dict(
            C=trial.suggest_float("svc_C", 1e-1, 10.0, log=True),
            kernel=kernel,
            degree=trial.suggest_int("svc_degree", 2, 5),
            shrinking=trial.suggest_categorical("svc_shrinking", [True, False]),
            random_state=31,
        )
        if kernel != "linear":
            svc_kwargs["gamma"] = trial.suggest_categorical("svc_gamma", ["scale", "auto"])
        if kernel in ("poly", "sigmoid"):
            svc_kwargs["coef0"] = trial.suggest_float("svc_coef0", 0.0, 7.0)
        cw = trial.suggest_categorical("svc_class_weight", ["balanced", "none"])
        if cw != "none":
            svc_kwargs["class_weight"] = cw
        model = svm.SVC(**svc_kwargs)
    elif model_name == "dt":
        mf = trial.suggest_categorical("dt_max_features", ["none", "sqrt", "log2"])
        model = DecisionTreeClassifier(
            criterion=trial.suggest_categorical("dt_criterion", ["gini", "entropy", "log_loss"]),
            splitter=trial.suggest_categorical("dt_splitter", ["best", "random"]),
            max_depth=trial.suggest_int("dt_max_depth", 2, 30),
            min_samples_split=trial.suggest_int("dt_min_split", 2, 20),
            min_samples_leaf=trial.suggest_int("dt_min_leaf", 1, 10),
            max_features=None if mf == "none" else mf,
            random_state=31,
        )
    from sklearn.model_selection import cross_val_score

    from imblearn.over_sampling import SMOTE
    from imblearn.pipeline import Pipeline
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])
    from sklearn.model_selection import StratifiedKFold
    cv = StratifiedKFold(
        n_splits=5,
        shuffle=True,
        random_state=31,
    )
    score = cross_val_score(
        pipe,
        X_train,
        y_train,
        cv=cv,
        scoring="accuracy",
        n_jobs=-1,
        error_score="raise"
    ).mean()

    return score
study = optuna.create_study(direction="maximize")
study.optimize(
    objective,
    n_trials=100,
    show_progress_bar=True,
)
print("best_accuracy:", study.best_value)
print("best_params:", study.best_params)
# Out:
# [I 2026-07-15 19:48:36,044] A new study created in memory with name: no-name-f1dd5bdd-ac2a-4e0b-9e7c-1524e4ecbd90
# Best trial: 0. Best value: 0.769537:   1%|          | 1/100 [00:00<01:02,  1.58it/s]
# [I 2026-07-15 19:48:36,676] Trial 0 finished with value: 0.7695374315276933 and parameters: {'model': 'svc', 'svc_kernel': 'linear', 'svc_C': 0.2392836321235167, 'svc_degree': 4, 'svc_shrinking': False, 'svc_class_weight': 'balanced'}. Best is trial 0 with value: 0.7695374315276933.
# Best trial: 1. Best value: 0.778145:   2%|▏         | 2/100 [00:01<01:38,  1.00s/it]
# [I 2026-07-15 19:48:37,940] Trial 1 finished with value: 0.7781453786627249 and parameters: {'model': 'svc', 'svc_kernel': 'rbf', 'svc_C': 2.492765713672746, 'svc_degree': 2, 'svc_shrinking': True, 'svc_gamma': 'auto', 'svc_class_weight': 'balanced'}. Best is trial 1 with value: 0.7781453786627249.
# Best trial: 1. Best value: 0.778145:   4%|▍         | 4/100 [00:02<00:58,  1.65it/s]
# [I 2026-07-15 19:48:38,714] Trial 2 finished with value: 0.6543054227168652 and parameters: {'model': 'svc', 'svc_kernel': 'sigmoid', 'svc_C': 2.7286396365360845, 'svc_degree': 2, 'svc_shrinking': False, 'svc_gamma': 'auto', 'svc_coef0': 1.0474704996714204, 'svc_class_weight': 'balanced'}. Best is trial 1 with value: 0.7781453786627249.
# [I 2026-07-15 19:48:38,871] Trial 3 finished with value: 0.7614598730545169 and parameters: {'model': 'dt', 'dt_max_features': 'none', 'dt_criterion': 'gini', 'dt_splitter': 'random', 'dt_max_depth': 30, 'dt_min_split': 5, 'dt_min_leaf': 10}. Best is trial 1 with value: 0.7781453786627249.
# Best trial: 1. Best value: 0.778145:   5%|▌         | 5/100 [00:03<00:42,  2.22it/s]
# [I 2026-07-15 19:48:39,046] Trial 4 finished with value: 0.6649595687331536 and parameters: {'model': 'dt', 'dt_max_features': 'log2', 'dt_criterion': 'log_loss', 'dt_splitter': 'best', 'dt_max_depth': 3, 'dt_min_split': 5, 'dt_min_leaf': 4}. Best is trial 1 with value: 0.7781453786627249.
# Best trial: 1. Best value: 0.778145:   6%|▌         | 6/100 [00:03<00:59,  1.58it/s]
# [I 2026-07-15 19:48:40,038] Trial 5 finished with value: 0.768999797119091 and parameters: {'model': 'svc', 'svc_kernel': 'linear', 'svc_C': 1.3026743667666834, 'svc_degree': 2, 'svc_shrinking': True, 'svc_class_weight': 'balanced'}. Best is trial 1 with value: 0.7781453786627249.
# Best trial: 1. Best value: 0.778145:   7%|▋         | 7/100 [00:05<01:25,  1.09it/s]
# [I 2026-07-15 19:48:41,540] Trial 6 finished with value: 0.768999797119091 and parameters: {'model': 'svc', 'svc_kernel': 'linear', 'svc_C': 1.1300905631571905, 'svc_degree': 3, 'svc_shrinking': True, 'svc_class_weight': 'balanced'}. Best is trial 1 with value: 0.7781453786627249.
# Best trial: 1. Best value: 0.778145:   8%|▊         | 8/100 [00:07<01:45,  1.14s/it]
# [I 2026-07-15 19:48:43,166] Trial 7 finished with value: 0.7738327101991131 and parameters: {'model': 'svc', 'svc_kernel': 'rbf', 'svc_C': 0.36933568937848005, 'svc_degree': 2, 'svc_shrinking': True, 'svc_gamma': 'auto', 'svc_class_weight': 'balanced'}. Best is trial 1 with value: 0.7781453786627249.
# Best trial: 1. Best value: 0.778145:   9%|▉         | 9/100 [00:11<03:27,  2.28s/it]
# [I 2026-07-15 19:48:47,956] Trial 8 finished with value: 0.766288438686491 and parameters: {'model': 'svc', 'svc_kernel': 'poly', 'svc_C': 5.065219093034795, 'svc_degree': 2, 'svc_shrinking': False, 'svc_gamma': 'scale', 'svc_coef0': 6.442313683016573, 'svc_class_weight': 'balanced'}. Best is trial 1 with value: 0.7781453786627249.
# Best trial: 10. Best value: 0.786223:  11%|█         | 11/100 [00:13<02:06,  1.42s/it]
# [I 2026-07-15 19:48:49,251] Trial 9 finished with value: 0.5950612990174766 and parameters: {'model': 'svc', 'svc_kernel': 'sigmoid', 'svc_C': 2.653416528964466, 'svc_degree': 4, 'svc_shrinking': False, 'svc_gamma': 'scale', 'svc_coef0': 5.728263351523645, 'svc_class_weight': 'none'}. Best is trial 1 with value: 0.7781453786627249.
# [I 2026-07-15 19:48:49,419] Trial 10 finished with value: 0.7862229371359013 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'best', 'dt_max_depth':
 'svc_class_weight': 'none'}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:50:35,945] Trial 47 finished with value: 0.7614598730545169 and parameters: {'model': 'dt', 'dt_max_features': 'none', 'dt_criterion': 'gini', 'dt_splitter': 'random', 'dt_max_depth': 28, 'dt_min_split': 20, 'dt_min_leaf': 10}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  49%|████▉     | 49/100 [02:00<01:20,  1.58s/it]
# [I 2026-07-15 19:50:36,094] Trial 48 finished with value: 0.7776033968060748 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'best', 'dt_max_depth': 24, 'dt_min_split': 7, 'dt_min_leaf': 10}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  51%|█████     | 51/100 [02:01<00:48,  1.01it/s]
# [I 2026-07-15 19:50:36,898] Trial 49 finished with value: 0.7770686606961714 and parameters: {'model': 'svc', 'svc_kernel': 'rbf', 'svc_C': 1.2100650412674498, 'svc_degree': 5, 'svc_shrinking': True, 'svc_gamma': 'scale', 'svc_class_weight': 'none'}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:50:37,054] Trial 50 finished with value: 0.7765165347940759 and parameters: {'model': 'dt', 'dt_max_features': 'log2', 'dt_criterion': 'log_loss', 'dt_splitter': 'best', 'dt_max_depth': 16, 'dt_min_split': 15, 'dt_min_leaf': 8}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  53%|█████▎    | 53/100 [02:01<00:26,  1.74it/s]
# [I 2026-07-15 19:50:37,254] Trial 51 finished with value: 0.7905327073008144 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'best', 'dt_max_depth': 19, 'dt_min_split': 20, 'dt_min_leaf': 8}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:50:37,416] Trial 52 finished with value: 0.7797379937976407 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'best', 'dt_max_depth': 17, 'dt_min_split': 19, 'dt_min_leaf': 9}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  55%|█████▌    | 55/100 [02:01<00:15,  2.85it/s]
# [I 2026-07-15 19:50:37,564] Trial 53 finished with value: 0.7802872214010376 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'best', 'dt_max_depth': 14, 'dt_min_split': 20, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:50:37,694] Trial 54 finished with value: 0.6913775613714749 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'best', 'dt_max_depth': 2, 'dt_min_split': 18, 'dt_min_leaf': 2}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  57%|█████▋    | 57/100 [02:01<00:10,  4.10it/s]
# [I 2026-07-15 19:50:37,844] Trial 55 finished with value: 0.7539054574964494 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'best', 'dt_max_depth': 10, 'dt_min_split': 20, 'dt_min_leaf': 4}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:50:37,979] Trial 56 finished with value: 0.7980697330666898 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'best', 'dt_max_depth': 21, 'dt_min_split': 19, 'dt_min_leaf': 8}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  59%|█████▉    | 59/100 [02:02<00:07,  5.44it/s]
# [I 2026-07-15 19:50:38,105] Trial 57 finished with value: 0.8061371474944208 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 21, 'dt_min_split': 17, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:50:38,232] Trial 58 finished with value: 0.808844158478973 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 21, 'dt_min_split': 15, 'dt_min_leaf': 6}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  60%|██████    | 60/100 [02:02<00:06,  5.98it/s]
# [I 2026-07-15 19:50:38,360] Trial 59 finished with value: 0.7404254702489639 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'gini', 'dt_splitter': 'random', 'dt_max_depth': 21, 'dt_min_split': 14, 'dt_min_leaf': 6}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  62%|██████▏   | 62/100 [02:03<00:15,  2.46it/s]
# [I 2026-07-15 19:50:39,642] Trial 60 finished with value: 0.7695374315276933 and parameters: {'model': 'svc', 'svc_kernel': 'linear', 'svc_C': 0.23888031741096583, 'svc_degree': 4, 'svc_shrinking': True, 'svc_class_weight': 'none'}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:50:39,827] Trial 61 finished with value: 0.7662855403877924 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 22, 'dt_min_split': 15, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  63%|██████▎   | 63/100 [02:04<00:15,  2.43it/s]
# [I 2026-07-15 19:50:40,250] Trial 62 finished with value: 0.8061371474944208 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 20, 'dt_min_split': 17, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  64%|██████▍   | 64/100 [02:04<00:15,  2.34it/s]
# [I 2026-07-15 19:50:40,710] Trial 63 finished with value: 0.8061371474944208 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 20, 'dt_min_split': 17, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  65%|██████▌   | 65/100 [02:05<00:15,  2.25it/s]
# [I 2026-07-15 19:50:41,188] Trial 64 finished with value: 0.8061371474944208 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 19, 'dt_min_split': 17, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:
. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  85%|████████▌ | 85/100 [02:09<00:03,  4.29it/s]
# [I 2026-07-15 19:50:45,691] Trial 83 finished with value: 0.7711662753963424 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 26, 'dt_min_split': 18, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:50:45,844] Trial 84 finished with value: 0.8061371474944208 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 22, 'dt_min_split': 17, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  86%|████████▌ | 86/100 [02:09<00:02,  4.88it/s]
# [I 2026-07-15 19:50:45,982] Trial 85 finished with value: 0.7630698779816247 and parameters: {'model': 'dt', 'dt_max_features': 'log2', 'dt_criterion': 'gini', 'dt_splitter': 'random', 'dt_max_depth': 28, 'dt_min_split': 16, 'dt_min_leaf': 8}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  87%|████████▋ | 87/100 [02:10<00:02,  4.52it/s]
# [I 2026-07-15 19:50:46,239] Trial 86 finished with value: 0.8007448627655567 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 20, 'dt_min_split': 17, 'dt_min_leaf': 6}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  89%|████████▉ | 89/100 [02:12<00:07,  1.46it/s]
# [I 2026-07-15 19:50:48,774] Trial 87 finished with value: 0.7716792742660059 and parameters: {'model': 'svc', 'svc_kernel': 'poly', 'svc_C': 0.7500572067949284, 'svc_degree': 5, 'svc_shrinking': True, 'svc_gamma': 'auto', 'svc_coef0': 1.817196048896749, 'svc_class_weight': 'none'}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:50:48,918] Trial 88 finished with value: 0.8007187780772685 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 24, 'dt_min_split': 16, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  91%|█████████ | 91/100 [02:13<00:03,  2.50it/s]
# [I 2026-07-15 19:50:49,050] Trial 89 finished with value: 0.7674173260296207 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 21, 'dt_min_split': 18, 'dt_min_leaf': 8}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:50:49,178] Trial 90 finished with value: 0.7479682926122366 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 16, 'dt_min_split': 14, 'dt_min_leaf': 6}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  92%|█████████▏| 92/100 [02:13<00:02,  3.09it/s]
# [I 2026-07-15 19:50:49,317] Trial 91 finished with value: 0.8061371474944208 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 29, 'dt_min_split': 17, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  94%|█████████▍| 94/100 [02:13<00:01,  3.92it/s]
# [I 2026-07-15 19:50:49,533] Trial 92 finished with value: 0.7662855403877924 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 30, 'dt_min_split': 15, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:50:49,706] Trial 93 finished with value: 0.7711662753963424 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 27, 'dt_min_split': 18, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  96%|█████████▌| 96/100 [02:14<00:00,  4.67it/s]
# [I 2026-07-15 19:50:49,877] Trial 94 finished with value: 0.8061371474944208 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 22, 'dt_min_split': 17, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:50:50,051] Trial 95 finished with value: 0.7603744601918674 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 29, 'dt_min_split': 16, 'dt_min_leaf': 8}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  97%|█████████▋| 97/100 [02:29<00:14,  4.82s/it]
# [I 2026-07-15 19:51:05,595] Trial 96 finished with value: 0.778141031214677 and parameters: {'model': 'svc', 'svc_kernel': 'poly', 'svc_C': 0.1778332615534215, 'svc_degree': 4, 'svc_shrinking': False, 'svc_gamma': 'scale', 'svc_coef0': 6.873295735254961, 'svc_class_weight': 'balanced'}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699:  98%|█████████▊| 98/100 [02:29<00:06,  3.49s/it]
# [I 2026-07-15 19:51:06,021] Trial 97 finished with value: 0.7711662753963424 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 26, 'dt_min_split': 18, 'dt_min_leaf': 7}. Best is trial 37 with value: 0.8626988957481959.
# Best trial: 37. Best value: 0.862699: 100%|██████████| 100/100 [02:30<00:00,  1.50s/it]
# [I 2026-07-15 19:51:06,267] Trial 98 finished with value: 0.7511303364924788 and parameters: {'model': 'dt', 'dt_max_features': 'sqrt', 'dt_criterion': 'gini', 'dt_splitter': 'random', 'dt_max_depth': 18, 'dt_min_split': 16, 'dt_min_leaf': 6}. Best is trial 37 with value: 0.8626988957481959.
# [I 2026-07-15 19:51:06,424] Trial 99 finished with value: 0.7862388777787438 and parameters: {'model': 'dt', 'dt_max_features': 'none', 'dt_criterion': 'entropy', 'dt_splitter': 'random', 'dt_max_depth': 24, 'dt_min_split': 17, 'dt_min_leaf': 6}. Best is trial 37 with value: 0.8626988957481959.
# best_accuracy: 0.8626988957481959
# best_params: {'model': 'svc', 'svc_kernel': 'poly', 'svc_C': 0.11802292497222219, 'svc_degree': 5, 'svc_shrinking': True, 'svc_gamma': 'scale', 'svc_coef0': 0.1498738862023643, 'svc_class_weight': 'none'}

# %%
# best_accuracy: 0.8901544793206388
# best_params: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0013480802798151305, 'logreg_max_iter': 1003, 'logreg_class_weight': 'none'}

# best_recall: 0.8416666666666668
# best_params: {'model': 'logreg', 'logreg_penalty': 'l1', 'logreg_solver': 'liblinear', 'logreg_C': 0.0031213419894754327, 'logreg_max_iter': 2263, 'logreg_class_weight': 'none'}

# best_f1: 0.50054816843983
# best_params: {'model': 'logreg', 'logreg_penalty': 'elasticnet', 'logreg_solver': 'saga', 'logreg_C': 0.0010121629721405313, 'logreg_max_iter': 2374, 'logreg_class_weight': 'none', 'logreg_l1_ratio': 0.5664248896508037}

# best_f1: 0.5234931545187387
# best_params: {'model': 'sgd', 'sgd_loss': 'hinge', 'sgd_penalty': 'l2', 'sgd_alpha': 0.9082478234465482, 'sgd_max_iter': 1398, 'sgd_lr': 'optimal', 'sgd_eta0': 0.4439584500502842}

# best_accuracy: 0.8901544793206388
# best_params: {'model': 'sgd', 'sgd_loss': 'hinge', 'sgd_penalty': 'l1', 'sgd_alpha': 0.5070110839447165, 'sgd_max_iter': 961, 'sgd_lr': 'constant', 'sgd_eta0': 0.01571404989972212}

# best_recall: 0.8375
# best_params: {'model': 'sgd', 'sgd_loss': 'log_loss', 'sgd_penalty': 'elasticnet', 'sgd_alpha': 0.012674428369697443, 'sgd_max_iter': 2876, 'sgd_lr': 'invscaling', 'sgd_eta0': 0.0015749352254016118}

# %%
from sklearn.linear_model import LogisticRegression, SGDClassifier
logreg_f1 = LogisticRegression(
    penalty="elasticnet",
    solver="saga",
    C=0.0010121629721405313,
    max_iter=2374,
    class_weight=None,
    l1_ratio=0.5664248896508037,
    random_state=31
)
sgd_f1 = SGDClassifier(
    loss="hinge",
    penalty="l2",
    alpha=0.9082478234465482,
    max_iter=1398,
    learning_rate="optimal",
    eta0=0.4439584500502842,
    random_state=31
)
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
numeric_features = X.select_dtypes(include=[np.number]).columns.tolist()
categorical_features = X.select_dtypes(include=["object", "category", "string"]).columns.tolist()
numeric_transformer = Pipeline([
    ("scaler", StandardScaler()),
])
categorical_transformer = Pipeline([
    ("onehot", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])
preprocessor = ColumnTransformer([
    ("num", numeric_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features),
])
pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", sgd_f1)
    ])
pipe.fit(X_train,y_train)
preds=pipe.predict(X_test)
print(classification_report(y_test, preds))
print(confusion_matrix(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       693
#            1       0.54      0.49      0.51       103
#
#     accuracy                           0.88       796
#    macro avg       0.73      0.71      0.72       796
# weighted avg       0.88      0.88      0.88       796
#
# [[651  42]
#  [ 53  50]]

# %%
import pickle

with open("student_dropout_model.pkl", "wb") as f:
    pickle.dump(pipe, f)
